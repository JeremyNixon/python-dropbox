# %%
import csv
import numpy as np
import pylab as pl
# %matplotlib inline
pl.rcParams['savefig.dpi'] = 300 
import math

# %%
csv_filename = 'motorcycle.csv'

# %%
times  = []
forces = []
with open(csv_filename, 'r') as csv_fh:

    # Parse as a CSV file.
    reader = csv.reader(csv_fh)

    # Skip the header line.
    next(reader, None)

    # Loop over the file.
    for row in reader:

        # Store the data.
        times.append(float(row[0]))
        forces.append(float(row[1]))

# Turn the data into numpy arrays.
times  = np.array(times)
forces = np.array(forces)

# %%
times
# Out:
# array([  2.4,   2.6,   3.2,   3.6,   4. ,   6.2,   6.6,   6.8,   7.8,
#          8.2,   8.8,   9.6,  10. ,  10.2,  10.6,  11. ,  11.4,  13.2,
#         13.6,  13.8,  14.6,  14.8,  15.4,  15.6,  15.8,  16. ,  16.2,
#         16.4,  16.6,  16.8,  17.6,  17.8,  18.6,  19.2,  19.4,  19.6,
#         20.2,  20.4,  21.2,  21.4,  21.8,  22. ,  23.2,  23.4,  24. ,
#         24.2,  24.6,  25. ,  25.4,  25.6,  26. ,  26.2,  26.4,  27. ,
#         27.2,  27.6,  28.2,  28.4,  28.6,  29.4,  30.2,  31. ,  31.2,
#         32. ,  32.8,  33.4,  33.8,  34.4,  34.8,  35.2,  35.4,  35.6,
#         36.2,  38. ,  39.2,  39.4,  40. ,  40.4,  41.6,  42.4,  42.8,
#         43. ,  44. ,  44.4,  45. ,  46.6,  47.8,  48.8,  50.6,  52. ,
#         53.2,  55. ,  55.4,  57.6])

# %%
forces
# Out:
# array([   0. ,   -1.3,   -2.7,    0. ,   -2.7,   -2.7,   -2.7,   -1.3,
#          -2.7,   -2.7,   -1.3,   -2.7,   -2.7,   -5.4,   -2.7,   -5.4,
#           0. ,   -2.7,   -2.7,    0. ,  -13.3,   -2.7,  -22.8,  -40.2,
#         -21.5,  -42.9,  -21.5,   -5.4,  -59. ,  -71. ,  -37.5,  -99.1,
#        -112.5, -123.1,  -85.6, -127.2, -123.1, -117.9, -134. , -101.9,
#        -108.4, -123.1, -123.1, -128.5, -112.5,  -95.1,  -53.5,  -64.4,
#         -72.3,  -26.8,   -5.4, -107.1,  -65.6,  -16. ,  -45.6,    4. ,
#          12. ,  -21.5,   46.9,  -17.4,   36.2,   75. ,    8.1,   54.9,
#          46.9,   16. ,   45.6,    1.3,   75. ,  -16. ,   69.6,   34.8,
#         -37.5,   46.9,    5.4,   -1.3,  -21.5,  -13.3,   30.8,   29.4,
#           0. ,   14.7,   -1.3,    0. ,   10.7,   10.7,  -26.8,  -13.3,
#           0. ,   10.7,  -14.7,   -2.7,   -2.7,   10.7])

# %%
# Create the simplest basis, with just the time and an offset.
X = np.vstack((np.ones(times.shape), times)).T
# Nothing fancy for outputs.
Y = forces

# %%
print X.shape
print arr.shape
print type(X)
print type(arr)
# Out:
# (94, 2)
# (94,)
# <type 'numpy.ndarray'>
# <type 'numpy.ndarray'>

# %%
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6]])
print np.concatenate((a, b), axis=0)
print a.shape
print b.shape
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# (2, 2)
# (1, 2)

# %%
X = np.column_stack((X, arr))
X
# Out:
# array([[   1.        ,    0.71462311,    0.71462311,    0.71462311,
#            0.71462311,    0.71462311,    0.71462311,    0.71462311,
#            0.71462311],
#        [   1.        ,    0.72905945,    0.72905945,    0.72905945,
#            0.72905945,    0.72905945,    0.72905945,    0.72905945,
#            0.72905945],
#        [   1.        ,    0.77414197,    0.77414197,    0.77414197,
#            0.77414197,    0.77414197,    0.77414197,    0.77414197,
#            0.77414197],
#        [   1.        ,    0.8057353 ,    0.8057353 ,    0.8057353 ,
#            0.8057353 ,    0.8057353 ,    0.8057353 ,    0.8057353 ,
#            0.8057353 ],
#        [   1.        ,    0.83861798,    0.83861798,    0.83861798,
#            0.83861798,    0.83861798,    0.83861798,    0.83861798,
#            0.83861798],
#        [   1.        ,    1.04498235,    1.04498235,    1.04498235,
#            1.04498235,    1.04498235,    1.04498235,    1.04498235,
#            1.04498235],
# ...

# %%
print times.shape
print arr.shape
print times
# Out:
# (94,)
# (94,)
# [  2.4   2.6   3.2   3.6   4.    6.2   6.6   6.8   7.8   8.2   8.8   9.6
#   10.   10.2  10.6  11.   11.4  13.2  13.6  13.8  14.6  14.8  15.4  15.6
#   15.8  16.   16.2  16.4  16.6  16.8  17.6  17.8  18.6  19.2  19.4  19.6
#   20.2  20.4  21.2  21.4  21.8  22.   23.2  23.4  24.   24.2  24.6  25.
#   25.4  25.6  26.   26.2  26.4  27.   27.2  27.6  28.2  28.4  28.6  29.4
#   30.2  31.   31.2  32.   32.8  33.4  33.8  34.4  34.8  35.2  35.4  35.6
#   36.2  38.   39.2  39.4  40.   40.4  41.6  42.4  42.8  43.   44.   44.4
#   45.   46.6  47.8  48.8  50.6  52.   53.2  55.   55.4  57.6]

# %%
arr = []
for times in times:
    arr.append(math.exp(-((times - 10*(1))/5.0**2)))
arr = np.asarray(arr)

# %%
arr
# Out:
# array([ 1.35526906,  1.34447016,  1.312587  ,  1.29175273,  1.27124915,
#         1.16416024,  1.14568189,  1.136553  ,  1.09198812,  1.07465534,
#         1.04917066,  1.01612869,  1.        ,  0.99203191,  0.97628571,
#         0.96078944,  0.94553914,  0.87985338,  0.86588775,  0.85898828,
#         0.8319358 ,  0.82530687,  0.8057353 ,  0.79931513,  0.79294612,
#         0.78662786,  0.78035994,  0.77414197,  0.76797354,  0.76185426,
#         0.73786087,  0.73198153,  0.70892893,  0.69211718,  0.68660233,
#         0.68113143,  0.66497888,  0.65968027,  0.63890468,  0.63381384,
#         0.62375351,  0.61878339,  0.58978336,  0.58508391,  0.57120906,
#         0.56665762,  0.55766325,  0.54881164,  0.54010052,  0.53579696,
#         0.52729242,  0.52309091,  0.51892288,  0.50661699,  0.50258023,
#         0.49460293,  0.48287377,  0.47902619,  0.47520927,  0.46024331,
#         0.44574867,  0.43171052,  0.42827062,  0.41478291,  0.40171998,
# ...

# %%
times
# Out:
# array([  2.4,   2.6,   3.2,   3.6,   4. ,   6.2,   6.6,   6.8,   7.8,
#          8.2,   8.8,   9.6,  10. ,  10.2,  10.6,  11. ,  11.4,  13.2,
#         13.6,  13.8,  14.6,  14.8,  15.4,  15.6,  15.8,  16. ,  16.2,
#         16.4,  16.6,  16.8,  17.6,  17.8,  18.6,  19.2,  19.4,  19.6,
#         20.2,  20.4,  21.2,  21.4,  21.8,  22. ,  23.2,  23.4,  24. ,
#         24.2,  24.6,  25. ,  25.4,  25.6,  26. ,  26.2,  26.4,  27. ,
#         27.2,  27.6,  28.2,  28.4,  28.6,  29.4,  30.2,  31. ,  31.2,
#         32. ,  32.8,  33.4,  33.8,  34.4,  34.8,  35.2,  35.4,  35.6,
#         36.2,  38. ,  39.2,  39.4,  40. ,  40.4,  41.6,  42.4,  42.8,
#         43. ,  44. ,  44.4,  45. ,  46.6,  47.8,  48.8,  50.6,  52. ,
#         53.2,  55. ,  55.4,  57.6])

# %%
print times.shape
print arr.shape
# Out:
# (94,)
# (94,)

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %% [markdown]
# φj(x) = exp{−((x − 10j)/5)2} for j = 0, . . . , 6

# %%
# Find the regression weights using the Moore-Penrose pseudoinverse.
w = np.linalg.solve(np.dot(X.T, X) , np.dot(X.T, Y))

# %%
np.dot(X.T, X)
# Out:
# array([[  9.40000000e+01,   2.43460000e+03,   5.73816288e+01],
#        [  2.43460000e+03,   8.11667600e+04,   1.09630749e+03],
#        [  5.73816288e+01,   1.09630749e+03,   4.41502648e+01]])

# %%
np.dot(X.T, Y)
# Out:
# array([ -2047.7 , -36981.32])

# %%
w
# Out:
# array([-44.74302734,   0.88644729])

# %%
# Compute the regression line on a grid of inputs.
grid_times = np.linspace(0, 60, 200)

# %%
grid_X = np.vstack((np.ones(grid_times.shape), grid_times))

# %%
grid_X.shape
# Out:
# (2, 200)

# %%
grid_Yhat  = np.dot(grid_X.T, w)

# %%
# Plot the data and the regression line.
pl.plot(times, forces, '.', grid_times, grid_Yhat, '-')
pl.xlabel("Times")
pl.ylabel("Forces")
pl.ylim([-500,500])

pl.show()

# %% [markdown]
# φj(x) = exp{−((x − 10j)/5)2} for j = 0, . . . , 6

# %%
print times.shape
print a.shape
print times
# Out:
# (94,)
# (94, 3)
# [  2.4   2.6   3.2   3.6   4.    6.2   6.6   6.8   7.8   8.2   8.8   9.6
#   10.   10.2  10.6  11.   11.4  13.2  13.6  13.8  14.6  14.8  15.4  15.6
#   15.8  16.   16.2  16.4  16.6  16.8  17.6  17.8  18.6  19.2  19.4  19.6
#   20.2  20.4  21.2  21.4  21.8  22.   23.2  23.4  24.   24.2  24.6  25.
#   25.4  25.6  26.   26.2  26.4  27.   27.2  27.6  28.2  28.4  28.6  29.4
#   30.2  31.   31.2  32.   32.8  33.4  33.8  34.4  34.8  35.2  35.4  35.6
#   36.2  38.   39.2  39.4  40.   40.4  41.6  42.4  42.8  43.   44.   44.4
#   45.   46.6  47.8  48.8  50.6  52.   53.2  55.   55.4  57.6]

# %%
a = np.vstack((np.ones(times.shape), times, times**times)).T
a = np.concatenate([a,times],axis=0)
a.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-a028ac24317b> in <module>()
#       1 a = np.vstack((np.ones(times.shape), times, times**times)).T
# ----> 2 a = np.concatenate([a,times],axis=0)
#       3 a.shape
#
# ValueError: all the input arrays must have same number of dimensions

# %%
import csv
import numpy as np
import pylab as pl

csv_filename = 'motorcycle.csv'

times  = []
forces = []
with open(csv_filename, 'r') as csv_fh:

    # Parse as a CSV file.
    reader = csv.reader(csv_fh)

    # Skip the header line.
    next(reader, None)

    # Loop over the file.
    for row in reader:

        # Store the data.
        times.append(float(row[0]))
        forces.append(float(row[1]))

# Turn the data into numpy arrays.
times  = np.array(times)
forces = np.array(forces)

# Plot the data.
# pl.plot(times, forces, 'o')
# pl.show()

# Create the simplest basis, with just the time and an offset.
X = np.ndarray((times.shape))
for j in range(0,7):
    arr = []
    for t in times:
        arr.append(math.exp(-(((t - 10*(j))/5.0)**2)))
    arr = np.asarray(arr)
    X = np.column_stack((X, arr))

# Nothing fancy for outputs.
Y = forces

# Find the regression weights using the Moore-Penrose pseudoinverse.
w = np.linalg.solve(np.dot(X.T, X) , np.dot(X.T, Y))

# Compute the regression line on a grid of inputs.
grid_times = np.linspace(0, 60, 200)

grid_X = np.vstack(grid_times).T
for i in range(0,7):
    arr = []
    for j in grid_times:
        arr.append(math.exp(-((j - 10*(i))/5.0)**2))
    arr = np.asarray(arr)
    grid_X = np.vstack((grid_X, arr))
    #grid_X = np.vstack((grid_X, grid_times))

grid_Yhat  = np.dot(grid_X.T, w)

# Plot the data and the regression line.
pl.plot(times, forces, 'o',
        grid_times, grid_Yhat, '-')
pl.ylim([-500,500])
pl.show()

# %%
w
# Out:
# array([  1.01610429e+01,  -2.00229124e+01,  -5.58570317e-02,
#         -1.31739917e+02,   3.08134542e+00,   3.37920148e+00,
#         -2.02573487e+01])

# %%
X.shape
# Out:
# (94, 7)

# %%
import csv
import numpy as np
import pylab as pl

csv_filename = 'motorcycle.csv'

times  = []
forces = []
with open(csv_filename, 'r') as csv_fh:

    # Parse as a CSV file.
    reader = csv.reader(csv_fh)

    # Skip the header line.
    next(reader, None)

    # Loop over the file.
    for row in reader:

        # Store the data.
        times.append(float(row[0]))
        forces.append(float(row[1]))

# Turn the data into numpy arrays.
times  = np.array(times)
forces = np.array(forces)

# Plot the data.
# pl.plot(times, forces, 'o')
# pl.show()

# Create the simplest basis, with just the time and an offset.
X = np.ndarray((times.shape))
for j in range(0,7):
    arr = []
    for t in times:
        arr.append(math.exp(-(((t - 10*(j))/10.0)**2)))
    arr = np.asarray(arr)
    X = np.column_stack((X, arr))

# Nothing fancy for outputs.
Y = forces

# Find the regression weights using the Moore-Penrose pseudoinverse.
w = np.linalg.solve(np.dot(X.T, X) , np.dot(X.T, Y))

# Compute the regression line on a grid of inputs.
grid_times = np.linspace(0, 60, 200)

grid_X = np.vstack(grid_times).T
for i in range(0,7):
    arr = []
    for j in grid_times:
        arr.append(math.exp(-((j - 10*(i))/10.0)**2))
    arr = np.asarray(arr)
    grid_X = np.vstack((grid_X, arr))
    #grid_X = np.vstack((grid_X, grid_times))

grid_Yhat  = np.dot(grid_X.T, w)

# Plot the data and the regression line.
pl.plot(times, forces, 'o',
        grid_times, grid_Yhat, '-')
pl.ylim([-500,500])
pl.show()

# %%
import csv
import numpy as np
import pylab as pl

csv_filename = 'motorcycle.csv'

times  = []
forces = []
with open(csv_filename, 'r') as csv_fh:

    # Parse as a CSV file.
    reader = csv.reader(csv_fh)

    # Skip the header line.
    next(reader, None)

    # Loop over the file.
    for row in reader:

        # Store the data.
        times.append(float(row[0]))
        forces.append(float(row[1]))

# Turn the data into numpy arrays.
times  = np.array(times)
forces = np.array(forces)

# Plot the data.
# pl.plot(times, forces, 'o')
# pl.show()

# Create the simplest basis, with just the time and an offset.
X = np.ndarray((times.shape))
for j in range(0,7):
    arr = []
    for t in times:
        arr.append(math.exp(-(((t - 10*(j))/25.0)**2)))
    arr = np.asarray(arr)
    X = np.column_stack((X, arr))

# Nothing fancy for outputs.
Y = forces

# Find the regression weights using the Moore-Penrose pseudoinverse.
w = np.linalg.solve(np.dot(X.T, X) , np.dot(X.T, Y))

# Compute the regression line on a grid of inputs.
grid_times = np.linspace(0, 60, 200)

grid_X = np.vstack(grid_times).T
for i in range(0,7):
    arr = []
    for j in grid_times:
        arr.append(math.exp(-((j - 10*(i))/25.0)**2))
    arr = np.asarray(arr)
    grid_X = np.vstack((grid_X, arr))
    #grid_X = np.vstack((grid_X, grid_times))

grid_Yhat  = np.dot(grid_X.T, w)

# Plot the data and the regression line.
pl.plot(times, forces, 'o',
        grid_times, grid_Yhat, '-')
pl.ylim([-500,500])
pl.show()

# %%
csv_filename = 'motorcycle.csv'

times  = []
forces = []
with open(csv_filename, 'r') as csv_fh:

    # Parse as a CSV file.
    reader = csv.reader(csv_fh)

    # Skip the header line.
    next(reader, None)

    # Loop over the file.
    for row in reader:

        # Store the data.
        times.append(float(row[0]))
        forces.append(float(row[1]))

# Turn the data into numpy arrays.
times  = np.array(times)
forces = np.array(forces)

X = np.ndarray(times.shape)
for j in range(2,11):
    arr = []
    for t in times:
        arr.append(t**j)
    arr = np.asarray(arr)
    X = np.column_stack((X, arr))

# Nothing fancy for outputs.
Y = forces

# Find the regression weights using the Moore-Penrose pseudoinverse.
w = np.linalg.solve(np.dot(X.T, X) , np.dot(X.T, Y))

# Compute the regression line on a grid of inputs.
grid_times = np.linspace(0, 60, 200)

grid_X = np.vstack(grid_times).T
for i in range(2,11):
    arr = []
    for t in grid_times:
        arr.append(t**i)
    arr = np.asarray(arr)
    grid_X = np.vstack((grid_X, arr))
    #grid_X = np.vstack((grid_X, grid_times))

grid_Yhat  = np.dot(grid_X.T, w)

# Plot the data and the regression line.
pl.plot(times, forces, 'o',
        grid_times, grid_Yhat, '-')
pl.ylim([-500,500])
pl.show()

# %%
X
# Out:
# array([[  2.40000000e+00,   2.40000000e+00,   5.76000000e+00, ...,
#           1.10075314e+03,   2.64180754e+03,   6.34033810e+03],
#        [  2.60000000e+00,   2.60000000e+00,   6.76000000e+00, ...,
#           2.08827065e+03,   5.42950368e+03,   1.41167096e+04],
#        [  3.20000000e+00,   3.20000000e+00,   1.02400000e+01, ...,
#           1.09951163e+04,   3.51843721e+04,   1.12589991e+05],
#        ...,
#        [  5.50000000e+01,   5.50000000e+01,   3.02500000e+03, ...,
#           8.37339379e+13,   4.60536658e+15,   2.53295162e+17],
#        [  5.54000000e+01,   5.54000000e+01,   3.06916000e+03, ...,
#           8.87315602e+13,   4.91572843e+15,   2.72331355e+17],
#        [  5.76000000e+01,   5.76000000e+01,   3.31776000e+03, ...,
#           1.21165748e+14,   6.97914708e+15,   4.01998872e+17]])

# %%
csv_filename = 'motorcycle.csv'

times  = []
forces = []
with open(csv_filename, 'r') as csv_fh:

    # Parse as a CSV file.
    reader = csv.reader(csv_fh)

    # Skip the header line.
    next(reader, None)

    # Loop over the file.
    for row in reader:

        # Store the data.
        times.append(float(row[0]))
        forces.append(float(row[1]))

# Turn the data into numpy arrays.
times  = np.array(times)
forces = np.array(forces)

X = np.ndarray(times.shape)
for j in range(2,11):
    arr = []
    for t in times:
        arr.append(math.sin(t/j))
    arr = np.asarray(arr)
    X = np.column_stack((X, arr))

# Nothing fancy for outputs.
Y = forces

# Find the regression weights using the Moore-Penrose pseudoinverse.
w = np.linalg.solve(np.dot(X.T, X) , np.dot(X.T, Y))

# Compute the regression line on a grid of inputs.
grid_times = np.linspace(0, 60, 200)

grid_X = np.vstack(grid_times).T
for i in range(2,11):
    arr = []
    for t in grid_times:
        arr.append(math.sin(t/i))
    arr = np.asarray(arr)
    grid_X = np.vstack((grid_X, arr))
    #grid_X = np.vstack((grid_X, grid_times))

grid_Yhat  = np.dot(grid_X.T, w)

# Plot the data and the regression line.
pl.plot(times, forces, 'o',
        grid_times, grid_Yhat, '-')
pl.ylim([-500,500])
pl.show()
