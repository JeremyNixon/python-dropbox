# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
url= "http://www.stat.columbia.edu/~gelman/arm/examples/speed.dating/Speed%20Dating%20Data.csv"
data = pd.read_csv(url)

# %%
data.to_csv('speed_dating.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
data.describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000
# mean     11.350919    16.872046     9.042731     9.295775     8.927668
# std       5.995903     4.358458     5.514939     5.650199     5.477009
# ...

# %%
data[:5]
# Out:
#    iid  id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1   1       0    1       1     1     10         7       NaN      4
# 1    1   1       0    1       1     1     10         7       NaN      3
# 2    1   1       0    1       1     1     10         7       NaN     10
# 3    1   1       0    1       1     1     10         7       NaN      5
# 4    1   1       0    1       1     1     10         7       NaN      7
#
#    partner  pid  match  int_corr  samerace  age_o  race_o  pf_o_att  pf_o_sin  \
# 0        1   11      0      0.14         0     27       2        35        20
# 1        2   12      0      0.54         0     22       2        60         0
# 2        3   13      1      0.16         1     22       4        19        18
# 3        4   14      1      0.61         0     23       2        30         5
# 4        5   15      1      0.21         0     24       3        30        10
#
# ...

# %%
plt.scatter(data['intel'],data['attr'])

# %%
plt.hist(data['intel'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-8c097d0e25f8> in <module>()
# ----> 1 plt.hist(data['intel'])
#
# /Users/Jeremy/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2825                       histtype=histtype, align=align, orientation=orientation,
#    2826                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2827                       stacked=stacked, **kwargs)
#    2828         draw_if_interactive()
#    2829     finally:
#
# /Users/Jeremy/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
# ...
