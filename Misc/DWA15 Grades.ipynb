# %%
import pandas as pd

# %%
grades = pd.read_csv('Grades-Dynamic_Web_Applications.csv')
grades[:5]
# Out:
#                Student      ID  SIS User ID  SIS Login ID  \
# 0                  NaN     NaN          NaN           NaN
# 1      Points Possible     NaN          NaN           NaN
# 2          Adair, Troy   43461     70954680      70954680
# 3       Agarwal, Ankit  101602     20961937      20961937
# 4      Agarwal, Dipesh    5846     70936127      70936127
#
#                                              Section  P1 (5944)  P2 (5945)  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN          5         10
# 2                              EXT CSCI E-15 (14291)        NaN        NaN
# 3  EXT CSCI E-15 (14291) and Johanna - Virtual, S...          5         10
# 4  EXT CSCI E-15 (14291) and Johanna - Virtual, S...          5         10
#
#    P3 (5946) P4 (5947)  Lecture 1 Quiz (Practice) (5957)  \
# 0        NaN     Muted                               NaN
# ...

# %%
grades.groupby('Section').P3.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-dd8cb46f4582> in <module>()
# ----> 1 grades.groupby('Section').P3.mean()
#
# /Users/Jeremy/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     484
#     485         raise AttributeError("%r object has no attribute %r" %
# --> 486                              (type(self).__name__, attr))
#     487
#     488     def __getitem__(self, key):
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'P3'
