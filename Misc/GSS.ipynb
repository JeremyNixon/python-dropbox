# %%
import pandas as pd

# %%
ls
# Out:
# Carolyn Gov 1010.ipynb
# Crime Playing.ipynb
# DWA15 Grades.ipynb
# GSS.ipynb
# GSS2012.csv
# Grades-Dynamic_Web_Applications.csv
# IV_DV.csv
# Obscured Hello World.ipynb
# Pew Research Global Attitudes Project Spring 2013 Dataset for Web/
# Pew Research Global Attitudes Project Spring 2013 Dataset for Web.zip
# Scraping Tennis Rankings.ipynb
# Speed Dating.ipynb
# Starcraft Scraping.ipynb
# Workshop/
# hello.py
# speed_dating.csv

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 1000)

# %%
data = pd.read_csv('GSS2012.csv')

data[:5]
# Out:
#    Unnamed: 0  year  id      wtss  vpsu  vstrat             res2008  \
# 0           1  2012   1  2.621963     1    3001  living in the u.s.
# 1           2  2012   2  3.495950     1    3001  living in the u.s.
# 2           3  2012   3  1.747975     1    3001  living in the u.s.
# 3           4  2012   4  1.235694     1    3001  living in the u.s.
# 4           5  2012   5  0.873988     1    3001  living in the u.s.
#
#               res2010  isco88  spisco88  paisco88  maisco88       mar1  \
# 0  living in the u.s.    3429       NaN      1233       NaN    married
# 1  living in the u.s.    3132       NaN       NaN      1231    married
# 2  living in the u.s.    2144      2331       NaN      3300    married
# 3  living in the u.s.    2411      1233      1210       NaN    married
# 4  living in the u.s.    5163       NaN      1319      7433  separated
#
#       mar2           mar3           mar4           mar5 mar6 mar7 mar8 mar11  \
# 0  married  never married            NaN            NaN  NaN  NaN  NaN   NaN
# 1  married  never married  never married  never married  NaN  NaN  NaN   NaN
# 2  married            NaN            NaN            NaN  NaN  NaN  NaN   NaN
# 3  married  never married            NaN            NaN  NaN  NaN  NaN   NaN
# 4      NaN            NaN            NaN            NaN  NaN  NaN  NaN   NaN
#
#   mar12 mar13 mar14 abany abdefect abhlth abnomore abpoor abrape absingle  \
# 0   NaN   NaN   NaN   yes      yes    yes      NaN    NaN    yes      NaN
# 1   NaN   NaN   NaN   yes      yes    yes      yes    yes    yes      yes
# 2   NaN   NaN   NaN   yes      yes    yes       no     no    yes       no
# 3   NaN   NaN   NaN   NaN      NaN    NaN      NaN    NaN    NaN      NaN
# 4   NaN   NaN   NaN   NaN      NaN    NaN      NaN    NaN    NaN      NaN
#
#                 accntsci         accptoth            acqntsex actupset  \
# 0                    NaN        most days  sex w acquaintance    never
# 1  not scientific at all  once in a while        not selected    never
# 2        very scientific        most days                 NaN    never
# 3     not too scientific              NaN                 NaN      NaN
# 4      pretty scientific              NaN                 NaN      NaN
#
#    adults        advfront     affrmact  age         aged  agekdbrn  \
# 0       3             NaN          NaN   22          NaN       NaN
# 1       4           agree          NaN   21  a good idea       NaN
# 2       2  strongly agree          NaN   42   a bad idea        32
# 3       3        disagree  oppose pref   49  a good idea        24
# 4       1  strongly agree  oppose pref   70      depends        24
#
#              architct arrest astrolgy               astrosci          attend  \
# 0                 NaN     no      NaN                    NaN     once a year
# 1  not too scientific     no      yes     sort of scientific             NaN
# 2                 NaN    yes      yes  not at all scientific             NaN
# 3                 NaN     no       no  not at all scientific             NaN
# 4     very scientific    yes       no        very scientific  lt once a year
#
#   away1 away11 away12 away2 away3 away4 away5 away6 away7 away8  babies  \
# 0   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 1   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 2   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 3   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# 4   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
#
#      ballot balneg             balpos    barate    betrlang          bible  \
# 0  ballot a    NaN                NaN      58%+         NaN  inspired word
# 1  ballot c    NaN  strongly in favor       NaN         NaN    word of god
# 2  ballot c    NaN  slightly in favor       NaN  language 1  inspired word
# 3  ballot b    NaN  strongly in favor       NaN         NaN  inspired word
# 4  ballot b    NaN  strongly in favor  40-57.9%         NaN    word of god
#
#   bigbang bigbang1           biosci bmitzvah born   bossemps boyorgrl  cappun  \
# 0     NaN      NaN              NaN      NaN  yes  very good      NaN     NaN
# 1    True      NaN              NaN      NaN  yes  very good     True   favor
# 2    True      NaN  very scientific      NaN  yes    neither     True     NaN
# 3     NaN     True  very scientific      NaN  yes        NaN     True   favor
# 4     NaN      NaN              NaN      NaN  yes        NaN     True  oppose
#
#         carecost                                           careprov  \
# 0  the employers  private childcare providers (e.g., private day...
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3     the family  private childcare providers (e.g., private day...
# 4     the family  private childcare providers (e.g., private day...
#
#          careself   caresik1                      carried  childs  chldidel  \
# 0           agree        NaN  not at all in the past year       0         2
# 1  strongly agree        NaN        once in the past year       0       NaN
# 2           agree        NaN        once in the past year       2       NaN
# 3             NaN  always me                          NaN       2         8
# 4             NaN        NaN                          NaN       3         2
#
#           class  closeblk  closewht           cmprgmng            cohabok  \
# 0   upper class         5         7                NaN              agree
# 1  middle class         6         7  pretty scientific                NaN
# 2  middle class         5         4                NaN                NaN
# 3   upper class       NaN       NaN                NaN              agree
# 4   lower class       NaN       NaN    very scientific  strongly disagree
#
#    cohort       colath     colcom     coldeg1      colhomo       colmil  \
# 0    1990      allowed  not fired         NaN      allowed  not allowed
# 1    1991  not allowed      fired         NaN  not allowed  not allowed
# 2    1970      allowed  not fired         NaN      allowed      allowed
# 3    1963          NaN        NaN         NaN          NaN          NaN
# 4    1942          NaN        NaN  bachelor's          NaN          NaN
#
#         colmslm       colrac colsci  colscinm comprend compuse       conarmy  \
# 0           NaN  not allowed    NaN       NaN     good     yes           NaN
# 1   not allowed  not allowed     no       NaN     good     NaN  a great deal
# 2  yes, allowed  not allowed    yes         1     good     NaN  a great deal
# 3           NaN          NaN     no       NaN     good     yes  a great deal
# 4           NaN          NaN    yes         1     good     yes  a great deal
#
#          conbus      conclerg          condom condrift       coneduc  \
# 0           NaN           NaN        not used      NaN           NaN
# 1  a great deal  a great deal        not used     True     only some
# 2     only some     only some  used last time     True     only some
# 3  a great deal  a great deal        not used     True     only some
# 4    hardly any     only some        not used     True  a great deal
#
#          confed      confinan        coninc      conjudge    conlabor  \
# 0           NaN           NaN  178712.46494           NaN         NaN
# 1     only some    hardly any  178712.46494  a great deal   only some
# 2     only some     only some   91920.00000     only some   only some
# 3    hardly any  a great deal  107240.00000     only some  hardly any
# 4  a great deal    hardly any   42130.00000  a great deal  hardly any
#
#        conlegis      conmedic    conpress  conrinc        consci  \
# 0           NaN           NaN         NaN      NaN           NaN
# 1  a great deal  a great deal  hardly any      NaN  a great deal
# 2    hardly any  a great deal   only some    91920  a great deal
# 3    hardly any  a great deal   only some      NaN           NaN
# 4    hardly any     only some  hardly any      NaN  a great deal
#
#                                              consent         contv convictd  \
# 0  r consents to partcipate in the survey but doe...           NaN       no
# 1                  r consents to recording interview  a great deal       no
# 2                  r consents to recording interview     only some      yes
# 3  r consents to partcipate in the survey but doe...     only some       no
# 4  r consents to partcipate in the survey but doe...    hardly any       no
#
#     cooking1                 coop            courts crack30  \
# 0        NaN  friendly,interested               NaN     NaN
# 1        NaN  friendly,interested  not harsh enough     NaN
# 2        NaN  friendly,interested               NaN     NaN
# 3  always me   restless,impatient               NaN     NaN
# 4        NaN  friendly,interested  not harsh enough     NaN
#
#              cshutyp08              cshutyp10  \
# 0  living in household  living in institution
# 1  living in household    living in household
# 2  living in household    living in household
# 3  living in household    living in household
# 4  living in household    living in household
#
#                                  cutahead  dateintv    deckids       degree  \
# 0  at least 2 or 3 times in the past year       721        NaN     bachelor
# 1             not at all in the past year       624        NaN  high school
# 2  at least 2 or 3 times in the past year       627        NaN  high school
# 3                                     NaN       527        NaN  high school
# 4                                     NaN       620  mostly me     bachelor
#
#                 denom             denom16 denyrais difstand  \
# 0                 NaN                 NaN    never   rarely
# 1                 NaN                 NaN    never   rarely
# 2     no denomination                 NaN   rarely    often
# 3  presbyterian-dk wh  presbyterian-dk wh      NaN      NaN
# 4    southern baptist                 NaN      NaN      NaN
#
#                 dipged                                directns  \
# 0  high school diploma                   once in the past year
# 1  high school diploma                   once in the past year
# 2  high school diploma  at least 2 or 3 times in the past year
# 3  high school diploma                                     NaN
# 4  high school diploma                                     NaN
#
#            discaff discaffm           discaffw            divbest  \
# 0  not very likely      NaN  somewhat unlikely  strongly disagree
# 1      very likely      NaN                NaN                NaN
# 2  not very likely      NaN                NaN                NaN
# 3              NaN      NaN  somewhat unlikely              agree
# 4              NaN      NaN        very likely     strongly agree
#
#            divlaw divorce dwell5              dwelling           dwelown  \
# 0  more difficult     NaN    NaN  detached 1-fam house  own or is buying
# 1             NaN     NaN    NaN  detached 1-fam house               NaN
# 2             NaN      no    NaN  detached 1-fam house               NaN
# 3       stay same     yes    NaN  detached 1-fam house  own or is buying
# 4          easier     NaN    NaN     2 units-one above  own or is buying
#
#    earnrs           earnshh          earthsun            econsci  educ  \
# 0       3               NaN               NaN                NaN    16
# 1       3               NaN  earth around sun                NaN    12
# 2       1               NaN  earth around sun    very scientific    12
# 3       2  i have no income  earth around sun  pretty scientific    13
# 4       0               NaN  earth around sun                NaN    16
#
#   eftotlt eharaswk                                        eldcost  \
# 0    468+    never                                            NaN
# 1     NaN    never                                            NaN
# 2     NaN   rarely                                            NaN
# 3     NaN      NaN  the elderly people themselves or their family
# 4    468+      NaN                    the government/public funds
#
#          eldersup                                 eldhelp electron  emailhr  \
# 0        disagree                          family members      NaN        4
# 1             NaN                                     NaN    False      NaN
# 2             NaN                                     NaN     True      NaN
# 3           agree  private providers of this kind of help      NaN        2
# 4  strongly agree                                     NaN    False        0
#
#    emailmin   engbrng engbtr  engda engdgr engdo engearn    engfun enggood  \
# 0       NaN       NaN    NaN    NaN    NaN   NaN     NaN       NaN     NaN
# 1       NaN       NaN    NaN    NaN    NaN   NaN     NaN       NaN     NaN
# 2       NaN       NaN    NaN    NaN    NaN   NaN     NaN       NaN     NaN
# 3       NaN  disagree  agree  happy    NaN  good     NaN  disagree   agree
# 4        30       NaN    NaN    NaN    NaN   NaN     NaN       NaN     NaN
#
#      engint   englone         engnring         engnrsci    engodd engprob  \
# 0       NaN       NaN              NaN              NaN       NaN     NaN
# 1       NaN       NaN  very scientific              NaN       NaN     NaN
# 2       NaN       NaN              NaN  very scientific       NaN     NaN
# 3  disagree  disagree              NaN  very scientific  disagree   agree
# 4       NaN       NaN  very scientific              NaN       NaN     NaN
#
#   engrel engresp engson  eqwlth             eth1     eth2      eth3  \
# 0    NaN     NaN    NaN     NaN            italy  germany   hungary
# 1    NaN     NaN    NaN       3            italy      NaN       NaN
# 2    NaN     NaN    NaN       5      west indies      NaN       NaN
# 3    NaN      no  happy       7  england & wales  germany  scotland
# 4    NaN     NaN    NaN       7           africa      NaN       NaN
#
#         ethnic           ethnum evcrack evdwell evharjb evidu evlosejb  \
# 0      germany  chooses 1 of 2+      no     NaN     NaN    no      NaN
# 1        italy          names 1      no     NaN     NaN    no      NaN
# 2  west indies          names 1      no     NaN     NaN    no      NaN
# 3          NaN  cannot choose 1      no     NaN     NaN    no      NaN
# 4       africa          names 1      no     NaN     NaN    no      NaN
#
#   evnegjob evolved evolved1 evpaidsx        evstray evwork  \
# 0      NaN     NaN      NaN       no  never married    NaN
# 1      NaN    True      NaN       no  never married    NaN
# 2      NaN    True      NaN       no             no    NaN
# 3      NaN     NaN    False       no             no    yes
# 4      NaN   False      NaN       no             no    yes
#
#                     expdesgn                exptext            fair  \
# 0                        NaN                    NaN             NaN
# 1  500 get the drug 500 dont  correct control group  take advantage
# 2      all 1000 get the drug     wrong other reason  take advantage
# 3  500 get the drug 500 dont   correct wrong reason            fair
# 4      all 1000 get the drug     wrong other reason  take advantage
#
#                      fambudgt           famdif16            famgen  \
# 0                         NaN                NaN  2 gens, children
# 1                         NaN  divorce,separated  2 gens, children
# 2                         NaN  divorce,separated  2 gens, children
# 3  i manage, give prtnr share                NaN  2 gens, children
# 4                         NaN  divorce,separated             1 gen
#
#              family16  famsuffr              famvswk1  \
# 0     mother & father     agree         once or twice
# 1              mother       NaN                   NaN
# 2              mother       NaN                   NaN
# 3     mother & father  disagree  doesn�t apply/no job
# 4  mother & stpfather  disagree  doesn�t apply/no job
#
#                                             famwkbst  \
# 0  the mother stays at home and the father works ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  the mother stays at home and the father works ...
#
#                                     famwklst            farming fear  \
# 0  both the mother and father work full-time                NaN   no
# 1                                        NaN  pretty scientific   no
# 2                                        NaN                NaN   no
# 3                                        NaN                NaN  NaN
# 4  both the mother and father work full-time    very scientific  NaN
#
#            fechld  feelevel     feeused     fefam                      fehire  \
# 0  strongly agree        75  yes, money  disagree  neither agree nor disagree
# 1             NaN        75  yes, money       NaN                         NaN
# 2             NaN        75  yes, money       NaN                         NaN
# 3           agree        20  yes, money     agree                    disagree
# 4           agree        75  yes, money  disagree                       agree
#
#   fejobaff     fepol  fepresch     finalter            finlcoun  \
# 0      NaN  disagree     agree  stayed same                 NaN
# 1      NaN       NaN       NaN       better  not too scientific
# 2      NaN       NaN       NaN       better                 NaN
# 3      NaN     agree  disagree       better                 NaN
# 4      NaN  disagree  disagree        worse     very scientific
#
#              finrela           fireftng           form  formwt  \
# 0      above average                NaN  alternate <y>       1
# 1      above average  pretty scientific  alternate <y>       1
# 2      above average                NaN   standard <x>       1
# 3      above average                NaN  alternate <y>       1
# 4  far below average  pretty scientific  alternate <y>       1
#
#                frndsex fucitzn            fund    fund16 gender1 gender10  \
# 0  had sex with friend     NaN        moderate  moderate    male      NaN
# 1  had sex with friend     NaN        moderate  moderate  female      NaN
# 2                  NaN     NaN        moderate  moderate    male      NaN
# 3                  NaN     NaN         liberal   liberal    male      NaN
# 4                  NaN     NaN  fundamentalist  moderate  female      NaN
#
#   gender11 gender12 gender13 gender14 gender2 gender3 gender4 gender5 gender6  \
# 0      NaN      NaN      NaN      NaN  female    male     NaN     NaN     NaN
# 1      NaN      NaN      NaN      NaN    male    male  female  female     NaN
# 2      NaN      NaN      NaN      NaN  female    male    male     NaN     NaN
# 3      NaN      NaN      NaN      NaN  female  female     NaN     NaN     NaN
# 4      NaN      NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
#
#   gender7 gender8 gender9      getahead                     givblood  \
# 0     NaN     NaN     NaN  both equally        once in the past year
# 1     NaN     NaN     NaN     hard work  not at all in the past year
# 2     NaN     NaN     NaN  luck or help  not at all in the past year
# 3     NaN     NaN     NaN           NaN                          NaN
# 4     NaN     NaN     NaN           NaN                          NaN
#
#                                  givchrty  \
# 0                   once in the past year
# 1  at least 2 or 3 times in the past year
# 2             not at all in the past year
# 3                                     NaN
# 4                                     NaN
#
#                                  givhmlss                      givseat  \
# 0  at least 2 or 3 times in the past year        once in the past year
# 1                   once in the past year  not at all in the past year
# 2             not at all in the past year        once in the past year
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#                   god        goodlife gradtounder  granborn      grass  \
# 0  believe but doubts             NaN       .211+         4        NaN
# 1  believe but doubts  strongly agree         NaN         0      legal
# 2   some higher power         neither         NaN         4      legal
# 3   some higher power         neither         NaN         0      legal
# 4     know god exists           agree       .211+         0  not legal
#
#    gunlaw hapcohab      hapmar         happy      happy7 harjob5     health  \
# 0  oppose      NaN         NaN    very happy  very happy     NaN       good
# 1   favor      NaN         NaN    very happy         NaN     NaN  excellent
# 2  oppose      NaN  very happy  pretty happy         NaN     NaN       good
# 3     NaN      NaN  very happy    very happy  very happy     NaN        NaN
# 4     NaN      NaN         NaN    very happy  very happy     NaN        NaN
#
#      health1     hefinfo                                helpaway  helpblk  \
# 0       good  1st person                   once in the past year      NaN
# 1        NaN  3rd person  at least 2 or 3 times in the past year        5
# 2        NaN  2nd person             not at all in the past year        4
# 3  excellent  1st person                                     NaN        5
# 4       good  1st person                                     NaN        4
#
#             helpful               helphwrk  \
# 0               NaN  more than once a week
# 1  lookout for self           once a month
# 2           helpful  once in the past year
# 3           helpful                    NaN
# 4           depends                    NaN
#
#                                         helpjob  helpnot        helpoth  \
# 0                                  once a month      NaN            NaN
# 1                         once in the past year        2  4th important
# 2  at least two or three times in the past year        3  3rd important
# 3                                           NaN        5  4th important
# 4                                           NaN        3  3rd important
#
#    helppoor  helpsick   hhclean1 hhrace                    hhtype  \
# 0       NaN       NaN        NaN  white  3adlts,2mar,sp,rel,0kids
# 1         3         4        NaN  white       4+adlts,2mar,1+kids
# 2         3         4        NaN  white         2adlts,mar,1+kids
# 3         5         5  always me  white  3adlts,2mar,sp,rel,0kids
# 4         1         2        NaN  black               1adlt,0kids
#
#                        hhtype1                                      hhwkfair  \
# 0  married couple, no children                                           NaN
# 1    married couple w children                                           NaN
# 2    married couple w children                                           NaN
# 3  married couple, no children  i do much more than my fair share of hh work
# 4                 single adult                                           NaN
#
#        hispanic                histsci hivtest  hivtest1        hivtest2  \
# 0  not hispanic                    NaN      no       NaN             NaN
# 1  not hispanic                    NaN      no       NaN             NaN
# 2     dominican     not too scientific     yes    199907  somewhere else
# 3  not hispanic  not scientific at all     yes    199206        hospital
# 4  not hispanic                    NaN      no       NaN             NaN
#
#     homekid           homosex  hompop hotcore                    housewrk  \
# 0  disagree  not wrong at all       3     NaN                    disagree
# 1       NaN      always wrong       5    True                         NaN
# 2       NaN  not wrong at all       4    True                         NaN
# 3  disagree               NaN       3    True  neither agree nor disagree
# 4  disagree               NaN       1     NaN                       agree
#
#    hrs1  hrs2 hsbio hschem                                    hsmath hsphys  \
# 0    15   NaN   NaN    NaN                                       NaN    NaN
# 1    30   NaN   yes    yes           geometry plane or solid or both     no
# 2    60   NaN   yes    yes  trigonometry linear programming analysis    yes
# 3   NaN   NaN   yes    yes                              pre-calculus    yes
# 4   NaN   NaN   yes     no                       one year of algebra     no
#
#    hubbywk1     hunt idu30 if08who ignorwk            incom16          income  \
# 0  disagree  neither   NaN   obama   never      above average  $25000 or more
# 1       NaN  neither   NaN   obama   never      above average  $25000 or more
# 2       NaN  neither   NaN     NaN   often      below average  $25000 or more
# 3  disagree      NaN   NaN     NaN     NaN  far above average  $25000 or more
# 4     agree      NaN   NaN     NaN     NaN      below average  $25000 or more
#
#              income06  indus10  intage                intecon  \
# 0     $150000 or over     7470      60                    NaN
# 1     $150000 or over      770      32  moderately interested
# 2  $110000 to $129999     6070      32        very interested
# 3  $130000 to $149999     6990      60        very interested
# 4     $50000 to 59999     9470      62        very interested
#
#                  inteduc               intenvir intethn  \
# 0                    NaN                    NaN   white
# 1  moderately interested        very interested   white
# 2  moderately interested  moderately interested   white
# 3  not at all interested  moderately interested   white
# 4        very interested        very interested   white
#
#                  intfarm       inthisp  intid                intintl  \
# 0                    NaN  not hispanic     49                    NaN
# 1  moderately interested  not hispanic    150  not at all interested
# 2  not at all interested  not hispanic    150  moderately interested
# 3  not at all interested  not hispanic     49  moderately interested
# 4  not at all interested  not hispanic    235  moderately interested
#
#    intlblks  intlwhts                 intmed                 intmil intrace1  \
# 0         4         4                    NaN                    NaN    white
# 1       NaN       NaN  moderately interested        very interested    white
# 2       NaN       NaN  moderately interested  moderately interested    white
# 3         4         4        very interested  not at all interested    white
# 4         5         5        very interested        very interested    white
#
#   intrace2 intrace3 intrhome                 intsci  intsex  \
# 0      NaN      NaN      NaN                    NaN  female
# 1      NaN      NaN      yes  moderately interested  female
# 2      NaN      NaN      yes  moderately interested  female
# 3      NaN      NaN      yes  not at all interested  female
# 4      NaN      NaN      yes        very interested  female
#
#                 intspace                inttech  intyrs      issp  jew jew16  \
# 0                    NaN                    NaN       2  did issp  NaN   NaN
# 1  moderately interested        very interested       0  did issp  NaN   NaN
# 2  not at all interested  moderately interested       0  did issp  NaN   NaN
# 3  not at all interested  moderately interested       2  did issp  NaN   NaN
# 4  moderately interested  moderately interested       2  did issp  NaN   NaN
#
#   jew16aj jewaj        jobfind jobhour  jobinc     joblose jobmeans  \
# 0     NaN   NaN  somewhat easy   fifth  second  not likely    third
# 1     NaN   NaN            NaN     NaN     NaN         NaN      NaN
# 2     NaN   NaN            NaN     NaN     NaN         NaN      NaN
# 3     NaN   NaN            NaN     NaN     NaN         NaN      NaN
# 4     NaN   NaN            NaN     NaN     NaN         NaN      NaN
#
#     jobpromo  jobsec       jobsecok              jobvsfa1    jokeswk  \
# 0  most impt  fourth  somewhat true         once or twice     rarely
# 1        NaN     NaN      very true                   NaN      never
# 2        NaN     NaN      very true                   NaN  sometimes
# 3        NaN     NaN            NaN  doesn�t apply/no job        NaN
# 4        NaN     NaN            NaN  doesn�t apply/no job        NaN
#
#                 journlsm kd1jwoth kd1relig kd2jwoth kd2relig kd3relig  \
# 0                    NaN      NaN      NaN      NaN      NaN      NaN
# 1     not too scientific      NaN      NaN      NaN      NaN      NaN
# 2                    NaN      NaN      NaN      NaN      NaN      NaN
# 3                    NaN      NaN      NaN      NaN      NaN      NaN
# 4  not scientific at all      NaN      NaN      NaN      NaN      NaN
#
#    kidfinbu                     kidjob                      kidjoy  kidnofre  \
# 0     agree                   disagree  neither agree nor disagree     agree
# 1       NaN                        NaN                         NaN       NaN
# 2       NaN                        NaN                         NaN       NaN
# 3     agree  neither agree or disagree  neither agree nor disagree  disagree
# 4  disagree          strongly disagree              strongly agree  disagree
#
#    kidnum                   kidsocst         kidssol           kidsuffr  \
# 0     NaN  neither agree or disagree             NaN              agree
# 1     NaN                        NaN     much better                NaN
# 2     NaN                        NaN             NaN                NaN
# 3     NaN  neither agree or disagree  somewhat worse  strongly disagree
# 4     NaN  neither agree or disagree  about the same           disagree
#
#     lackinfo lasers    laundry1               lawenfrc  \
# 0     rarely    NaN         NaN                    NaN
# 1      never    NaN         NaN  not scientific at all
# 2  sometimes  False         NaN                    NaN
# 3        NaN    NaN  usually me                    NaN
# 4        NaN  False         NaN      pretty scientific
#
#                         lentto letdie1              letin1      libath  \
# 0        once in the past year      no    reduced a little         NaN
# 1  not at all in the past year     NaN                 NaN  not remove
# 2  not at all in the past year     NaN                 NaN  not remove
# 3                          NaN     yes    reduced a little         NaN
# 4                          NaN      no  increased a little         NaN
#
#        libcom     libhomo      libmil     libmslm      librac liedcwkr  \
# 0  not remove  not remove  not remove      remove         NaN    never
# 1  not remove  not remove  not remove      remove  not remove    never
# 2  not remove  not remove  not remove  not remove  not remove      NaN
# 3         NaN         NaN         NaN         NaN         NaN      NaN
# 4         NaN         NaN         NaN         NaN         NaN      NaN
#
#        life                  liveblks                  livewhts  lngthinv  \
# 0  exciting  neither favor nor oppose            strongly favor        69
# 1  exciting                       NaN                       NaN        53
# 2  exciting                       NaN                       NaN        77
# 3       NaN  neither favor nor oppose                     favor        78
# 4       NaN                    oppose  neither favor nor oppose       149
#
#                       loanitem localnum lockedup           lookaway losejob5  \
# 0  not at all in the past year      1-9       no  strongly disagree      NaN
# 1  not at all in the past year      1-9       no  strongly disagree      NaN
# 2        once in the past year   2,000+       no           disagree      NaN
# 3                          NaN      NaN       no                NaN      NaN
# 4                          NaN      NaN       no                NaN      NaN
#
#             madeg  maeduc  maind10 majew  \
# 0        bachelor      16      NaN   NaN
# 1     high school      12     2190   NaN
# 2  junior college      15     8470   NaN
# 3        bachelor      16      NaN   NaN
# 4     high school      12     8090   NaN
#
#                                       major1 major2           majorcol  \
# 0                                    english    NaN                NaN
# 1                                        NaN    NaN                NaN
# 2                                        NaN    NaN                NaN
# 3                                        NaN    NaN                NaN
# 4  political science/international relations    NaN  political science
#
#   majwoth  maocc10                  marasian                    marblk  \
# 0     NaN      NaN  neither favor nor oppose  neither favor nor oppose
# 1     NaN      100                       NaN                       NaN
# 2     NaN     2540                       NaN                       NaN
# 3     NaN      NaN                     favor                     favor
# 4     NaN     8350  neither favor nor oppose            strongly favor
#
#   marelig                    marhappy                   marhisp  \
# 0     NaN  neither agree nor disagree  neither favor nor oppose
# 1     NaN                         NaN                       NaN
# 2     NaN                         NaN                       NaN
# 3     NaN  neither agree nor disagree                     favor
# 4     NaN  neither agree nor disagree  neither favor nor oppose
#
#              marhomo        marital        marlegit               marrcoun  \
# 0     strongly agree  never married           agree                    NaN
# 1  strongly disagree  never married             NaN  not scientific at all
# 2     strongly agree        married             NaN                    NaN
# 3                NaN        married           agree                    NaN
# 4                NaN      separated  strongly agree  not scientific at all
#
#                      marwht matesex mawork14 mawrkgrw      mawrkslf mawrkwrm  \
# 0  neither favor nor oppose     yes       no       no           NaN    agree
# 1                       NaN      no      NaN      yes  someone else      NaN
# 2                       NaN     yes      NaN      yes  someone else      NaN
# 3            strongly favor     NaN       no       no           NaN    agree
# 4            strongly favor     NaN      yes      yes  someone else    agree
#
#               medsci         medtreat                    meovrwrk  mntlhlth  \
# 0                NaN              NaN                       agree        10
# 1                NaN  very scientific                         NaN         0
# 2    very scientific              NaN                         NaN         5
# 3  pretty scientific              NaN  neither agree nor disagree       NaN
# 4                NaN  very scientific                       agree       NaN
#
#            mobile16       mode    nataid      nataidy   natarms     natarmsy  \
# 0  same st,dif city  in-person       NaN  about right       NaN     too much
# 1         same city  in-person       NaN     too much       NaN  about right
# 2   different state  in-person  too much          NaN  too much          NaN
# 3  same st,dif city  in-person       NaN     too much       NaN  about right
# 4         same city  in-person       NaN  about right       NaN   too little
#
#        natchld      natcity     natcityy     natcrime     natcrimy natdrug  \
# 0  about right          NaN   too little          NaN  about right     NaN
# 1  about right          NaN  about right          NaN   too little     NaN
# 2   too little  about right          NaN  about right          NaN     NaN
# 3          NaN          NaN  about right          NaN   too little     NaN
# 4  about right          NaN          NaN          NaN  about right     NaN
#
#       natdrugy     nateduc    nateducy     natenrgy     natenvir     natenviy  \
# 0  about right         NaN  too little   too little          NaN   too little
# 1     too much         NaN  too little   too little          NaN   too little
# 2          NaN  too little         NaN  about right  about right          NaN
# 3  about right         NaN  too little   too little          NaN     too much
# 4   too little         NaN  too little   too little          NaN  about right
#
#        natfare    natfarey   natheal     nathealy      natmass      natpark  \
# 0          NaN  too little       NaN  about right   too little  about right
# 1          NaN    too much       NaN   too little  about right  about right
# 2  about right         NaN  too much          NaN          NaN   too little
# 3          NaN    too much       NaN  about right  about right     too much
# 4          NaN  too little       NaN   too little  about right  about right
#
#        natrace     natracey      natroad       natsci       natsoc  \
# 0          NaN  about right     too much  about right   too little
# 1          NaN  about right  about right   too little     too much
# 2  about right          NaN   too little   too little  about right
# 3          NaN          NaN   too little     too much          NaN
# 4          NaN  about right   too little   too little   too little
#
#        natspac  natspacy negjob5              news newsfrom nextgen  numcong  \
# 0          NaN       NaN     NaN       once a week      NaN     NaN      NaN
# 1          NaN  too much     NaN               NaN       tv   agree      NaN
# 2  about right       NaN     NaN               NaN       tv   agree      NaN
# 3          NaN       NaN     NaN  few times a week       tv   agree      NaN
# 4          NaN  too much     NaN  few times a week       tv   agree      NaN
#
#    numemps  numkids  nummen  numwomen           obey  occ10 odds1 odds2  old1  \
# 0      NaN        2       0         4            NaN   4800   NaN   NaN    48
# 1      NaN      NaN       0         8  2nd important   2900    no   yes    45
# 2      NaN      NaN       0        12  4th important   1320    no   yes    42
# 3      NaN      NaN       5         0  2nd important    800    no   yes    56
# 4      NaN        3       6         0  4th important   3800    no    no    71
#
#    old10  old11  old12  old13  old14  old2  old3  old4  old5  old6  old7  \
# 0    NaN    NaN    NaN    NaN    NaN    47    21   NaN   NaN   NaN   NaN
# 1    NaN    NaN    NaN    NaN    NaN    44    21    18    14   NaN   NaN
# 2    NaN    NaN    NaN    NaN    NaN   NaN    10     6   NaN   NaN   NaN
# 3    NaN    NaN    NaN    NaN    NaN    48    23   NaN   NaN   NaN   NaN
# 4    NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    old8  old9 oth16   othcredt  other      othersex othjew othjew16 othlang  \
# 0   NaN   NaN   NaN      never    NaN  not selected    NaN      NaN      no
# 1   NaN   NaN   NaN      never    NaN  not selected    NaN      NaN      no
# 2   NaN   NaN   NaN  sometimes    NaN           NaN    NaN      NaN     yes
# 3   NaN   NaN   NaN        NaN    NaN           NaN    NaN      NaN      no
# 4   NaN   NaN   NaN        NaN    NaN           NaN    NaN      NaN      no
#
#   othlang1 othlang2                    othshelp  oversamp owngun  \
# 0      NaN      NaN                       agree         1     no
# 1      NaN      NaN  neither agree nor disagree         1     no
# 2  spanish      NaN  neither agree nor disagree         1     no
# 3      NaN      NaN                         NaN         1    NaN
# 4      NaN      NaN                         NaN         1    NaN
#
#             padeg  paeduc             paidlv  paidlv1  \
# 0        graduate      16  yes, enter months        8
# 1             NaN     NaN                NaN      NaN
# 2             NaN     NaN                NaN      NaN
# 3        graduate      18  yes, enter months        2
# 4  lt high school     NaN  yes, enter months       12
#
#                                             paidlvdv  \
# 0  the mother and the father should each take hal...
# 1                                                NaN
# 2                                                NaN
# 3  the mother should take most of the paid leave ...
# 4  the mother and the father should each take hal...
#
#                            paidlvpy       paidsex  paind10 pajew pajwoth  \
# 0  both government and the employer  not selected     4380   NaN     NaN
# 1                               NaN  not selected      NaN   NaN     NaN
# 2                               NaN           NaN      NaN   NaN     NaN
# 3                      the employer           NaN     1870   NaN     NaN
# 4                     other sources           NaN     8770   NaN     NaN
#
#    paocc10         parborn parelig          parsol   partfull     partners  \
# 0     4710     both in u.s     NaN             NaN  part-time   2 partners
# 1      NaN     both in u.s     NaN     much better  full-time   2 partners
# 2      NaN  neither in u.s     NaN     much better  full-time    1 partner
# 3       10     both in u.s     NaN  somewhat worse        NaN  no partners
# 4      430     both in u.s     NaN     much better        NaN  no partners
#
#          partnrs5             partyid       pawrkslf  \
# 0   5-10 partners        ind,near dem   someone else
# 1  11-20 partners        ind,near rep            NaN
# 2       1 partner        ind,near dem            NaN
# 3       1 partner  not str republican   someone else
# 4       1 partner     strong democrat  self-employed
#
#                      peoptrbl                          phase          phone  \
# 0  neither agree nor disagree  phase two - sub sampled cases      cellphone
# 1  neither agree nor disagree  phase two - sub sampled cases      cellphone
# 2                       agree  phase two - sub sampled cases  phone in home
# 3                         NaN      phase one - initial cases  phone in home
# 4                         NaN  phase two - sub sampled cases  phone in home
#
#           physcsci      pikupsex pillok pistol polabuse polattak  poleff11  \
# 0              NaN  not selected  agree     no      NaN      NaN       NaN
# 1              NaN  not selected    NaN     no      yes      yes       NaN
# 2  very scientific           NaN    NaN     no       no      yes  disagree
# 3  very scientific           NaN  agree    NaN      yes      yes       NaN
# 4              NaN           NaN  agree    NaN       no      yes       NaN
#
#   poleff13  poleff15  poleff16                    poleff17            poleff3  \
# 0      NaN       NaN       NaN                         NaN                NaN
# 1      NaN       NaN       NaN                         NaN                NaN
# 2    agree  disagree  disagree  neither agree nor disagree  strongly disagree
# 3      NaN       NaN       NaN                         NaN                NaN
# 4      NaN       NaN       NaN                         NaN                NaN
#
#    polefy11  polefy13  polefy15 polefy16 polefy17      polefy3 polescap  \
# 0      some  a little  a little      NaN     most         some      NaN
# 1  a little      some  a little   rarely     some  quite a bit      yes
# 2       NaN       NaN       NaN      NaN      NaN          NaN      yes
# 3       NaN       NaN       NaN      NaN      NaN          NaN      yes
# 4       NaN       NaN       NaN      NaN      NaN          NaN      yes
#
#   polhitok polmurdr              polviews                 popespks  \
# 0      NaN      NaN              moderate  uncertain true or false
# 1      yes       no  slghtly conservative            probably true
# 2      yes       no  slghtly conservative                      NaN
# 3      yes       no  slghtly conservative                      NaN
# 4      yes       no               liberal                      NaN
#
#            popular           pornlaw                posslq  \
# 0              NaN               NaN                   NaN
# 1  least important  illegal under 18                   NaN
# 2   most important  illegal under 18  married with partner
# 3  least important  illegal under 18                   NaN
# 4  least important  illegal under 18                   NaN
#
#                                              posslqy postlife  \
# 0  i have a husband or wife or steady partner, bu...      yes
# 1  i have a husband or wife or steady partner, bu...      yes
# 2                                                NaN      yes
# 3  i am married and living in the same household ...      yes
# 4  i have a husband or wife or steady partner, bu...      NaN
#
#                   pray      prayer          premarsx  pres08     prespop  \
# 0          once a week     approve  not wrong at all     NaN     approve
# 1                never         NaN               NaN     NaN         NaN
# 2  several times a day         NaN               NaN   obama         NaN
# 3                never     approve  not wrong at all  mccain  disapprove
# 4  several times a day  disapprove  not wrong at all   obama     approve
#
#    preteen putdown racdif1 racdif2 racdif3 racdif4   race  \
# 0        0   never     yes      no      no      no  white
# 1        0   never     NaN     NaN     NaN     NaN  white
# 2        2   often     NaN     NaN     NaN     NaN  other
# 3        0     NaN     NaN      no     yes     yes  white
# 4        0     NaN      no      no      no      no  black
#
#                     racecen1 racecen2 racecen3 raclive            racopen  \
# 0                      white      NaN      NaN     yes  cant discriminate
# 1                      white      NaN      NaN     yes      owner decides
# 2                   hispanic      NaN      NaN      no  cant discriminate
# 3                      white      NaN      NaN      no                NaN
# 4  black or african american      NaN      NaN     yes                NaN
#
#         racwork radioact  rank  ratetone      realinc  realrinc reborn  \
# 0     all white      NaN     3         2  155139.9731       NaN     no
# 1     all white    False     4         3  155139.9731       NaN     no
# 2  mostly white    False     6         5   58800.0000     58800     no
# 3           NaN    False     4         2   68600.0000       NaN     no
# 4           NaN     True     5         5   26950.0000       NaN     no
#
#              reg16           region relactiv            relate1 relate10  \
# 0      new england      new england    never  head of household      NaN
# 1      new england      new england    never  head of household      NaN
# 2  middle atlantic      new england    never  head of household      NaN
# 3      new england      new england    never  head of household      NaN
# 4  middle atlantic  middle atlantic    never  head of household      NaN
#
#   relate11 relate12 relate13 relate14 relate2 relate3 relate4 relate5 relate6  \
# 0      NaN      NaN      NaN      NaN  spouse   child     NaN     NaN     NaN
# 1      NaN      NaN      NaN      NaN  spouse   child   child   child     NaN
# 2      NaN      NaN      NaN      NaN  spouse   child   child     NaN     NaN
# 3      NaN      NaN      NaN      NaN  spouse   child     NaN     NaN     NaN
# 4      NaN      NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
#
#   relate7 relate8 relate9              relatsex       relhh1 relhh10 relhh11  \
# 0     NaN     NaN     NaN  yes, in relationship  householder     NaN     NaN
# 1     NaN     NaN     NaN  yes, in relationship  householder     NaN     NaN
# 2     NaN     NaN     NaN  yes, in relationship  householder     NaN     NaN
# 3     NaN     NaN     NaN  yes, in relationship  householder     NaN     NaN
# 4     NaN     NaN     NaN  yes, in relationship  householder     NaN     NaN
#
#   relhh12 relhh13 relhh14  relhh2            relhh3            relhh4  \
# ...
# 0  completely satisfied       satisfied   very satisfied  very satisfied
# 1                   NaN       satisfied   very satisfied             NaN
# 2                   NaN    more or less  a little dissat             NaN
# 3        very satisfied       satisfied              NaN             NaN
# 4        very satisfied  not at all sat              NaN             NaN
#
#   savesoul          scibnfts  sciental        scientbe           scientbr  \
# 0       no               NaN       NaN             NaN                NaN
# 1       no  benefits greater  disagree  strongly agree  strongly disagree
# 2      yes  benefits greater  disagree        disagree                NaN
# 3       no  benefits greater       NaN             NaN                NaN
# 4      yes  benefits greater  disagree  strongly agree  strongly disagree
#
#   scientda  scientdn   scientdo  scientfu        scientgo        scienthe  \
# 0      NaN       NaN        NaN       NaN             NaN             NaN
# 1    happy     agree       fair  disagree  strongly agree  strongly agree
# 2    happy  disagree       fair       NaN           agree           agree
# 3      NaN       NaN        NaN       NaN             NaN             NaN
# 4    happy  disagree  very poor  disagree           agree  strongly agree
#
#    scientmo  scientod scientr           scientre scientsn  scientwk  \
# 0       NaN       NaN     NaN                NaN      NaN       NaN
# 1  disagree  disagree      no  strongly disagree    happy  disagree
# 2  disagree  disagree     yes           disagree    happy  disagree
# 3       NaN       NaN     NaN                NaN      NaN       NaN
# 4  disagree     agree      no              agree    happy  disagree
#
#               scifrom scinews1 scinews2 scinews3             scistudy  \
# 0                 NaN      NaN      NaN      NaN                  NaN
# 1  friends colleagues      NaN      NaN      NaN        general sense
# 2                  tv      NaN      NaN      NaN        general sense
# 3                  tv      NaN      NaN      NaN        general sense
# 4                  tv      NaN      NaN      NaN  clear understanding
#
#           scitext                   sector       seeksci  \
# 0             NaN  public, 4-year or above           NaN
# 1  classification                      NaN            tv
# 2  classification                      NaN  the internet
# 3     measurement                      NaN  the internet
# 4  classification  public, 4-year or above            tv
#
#                      selffrst         selfless     sex sexeduc       sexfreq  \
# 0  neither agree nor disagree        most days    male   favor  2-3 per week
# 1              strongly agree        some days    male     NaN   4+ per week
# 2  neither agree nor disagree  once in a while    male     NaN        weekly
# 3                         NaN              NaN  female   favor           NaN
# 4                         NaN              NaN  female   favor           NaN
#
#                     sexornt              sexsex    sexsex18  \
# 0  heterosexual or straight  exclusively female  only women
# 1  heterosexual or straight  exclusively female  only women
# 2  heterosexual or straight  exclusively female  only women
# 3  heterosexual or straight                 NaN    only men
# 4  heterosexual or straight                 NaN    only men
#
#               sexsex5       shop1 shotgun  shout  sibs  singlpar  size  \
# 0  exclusively female         NaN      no  never     1     agree    14
# 1  exclusively female         NaN      no  never     2       NaN    14
# 2  exclusively female         NaN      no  often     1       NaN    14
# 3    exclusively male  usually me     NaN    NaN     2     agree    14
# 4    exclusively male         NaN     NaN    NaN     0  disagree    24
#
#                 slsmnshp            socbar          socfrend  \
# 0                    NaN  sev times a week      once a month
# 1  not scientific at all               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN             never       once a year
# 4  not scientific at all             never  sev times a year
#
#            socommun            socrel             socsci  solarrev  spaneng  \
# 0  sev times a week  sev times a mnth                NaN       NaN  english
# 1               NaN               NaN                NaN  one year  english
# 2               NaN               NaN  pretty scientific  one year  english
# 3             never  sev times a year  pretty scientific   one day  english
# 4      once a month  sev times a week                NaN  one year  english
#
#   spanint        spanking spanself spbarate     spdeg            spden  \
# 0     NaN           agree      NaN      NaN       NaN              NaN
# 1     NaN             NaN      NaN      NaN       NaN              NaN
# 2     NaN             NaN      NaN     58%+  bachelor  no denomination
# 3     NaN           agree      NaN     58%+  bachelor              NaN
# 4     NaN  strongly agree      NaN      NaN       NaN              NaN
#
#               spdipged  speduc speftotlt spevwork  spfalook    spfund  \
# 0                  NaN     NaN       NaN      NaN       NaN       NaN
# 1                  NaN     NaN       NaN      NaN       NaN       NaN
# 2  high school diploma      16      468+      yes       NaN  moderate
# 3  high school diploma      16      468+      NaN         0  moderate
# 4                  NaN     NaN       NaN      NaN       NaN       NaN
#
#   spgradtounder  sphhwork  sphrs1  sphrs2  spind10 spjew spjew16  spjewaj  \
# 0           NaN       NaN     NaN     NaN      NaN   NaN     NaN        0
# 1           NaN       NaN     NaN     NaN      NaN   NaN     NaN        0
# 2         .211+       NaN     NaN     NaN     7860   NaN     NaN        0
# 3         .211+         0      60     NaN     4770   NaN     NaN        0
# 4           NaN       NaN     NaN     NaN      NaN   NaN     NaN        0
#
#   spjoth16   spkath       spkcom      spkhomo   spklang   spkmil  \
# 0      NaN      NaN  not allowed      allowed       NaN  allowed
# 1      NaN  allowed      allowed  not allowed       NaN  allowed
# 2      NaN  allowed      allowed      allowed  not well  allowed
# 3      NaN      NaN          NaN          NaN       NaN      NaN
# 4      NaN      NaN          NaN          NaN       NaN      NaN
#
#         spkmslm       spkrac  splive  spocc10 spother spothjew       sprel  \
# 0   not allowed  not allowed     NaN      NaN     NaN      NaN         NaN
# 1   not allowed      allowed     NaN      NaN     NaN      NaN         NaN
# 2  yes, allowed      allowed     NaN     2310     NaN      NaN  protestant
# 3           NaN          NaN      19     4700     NaN      NaN    catholic
# 4           NaN          NaN     NaN      NaN     NaN      NaN         NaN
#
#   sprel16          sprtprsn                                 spsector  \
# 0     NaN  modeate spirtual                                      NaN
# 1     NaN  slight spiritual                                      NaN
# 2     NaN  slight spiritual  private not-for-profit, 4-year or above
# 3     NaN  slight spiritual  private not-for-profit, 4-year or above
# 4     NaN  modeate spirtual                                      NaN
#
#         spwrkslf          spwrksta         srcbelt  ssfchild  \
# 0            NaN               NaN  suburb, 13-100     agree
# 1            NaN               NaN  suburb, 13-100       NaN
# 2   someone else     keeping house  suburb, 13-100       NaN
# 3  self-employed  working fulltime  suburb, 13-100     agree
# 4            NaN               NaN     other urban  disagree
#
#             ssmchild suicide1 suicide2 suicide3 suicide4       supcares  \
# 0              agree       no       no       no       no      very true
# 1                NaN      NaN      NaN      NaN      NaN      very true
# 2                NaN      NaN      NaN      NaN      NaN  somewhat true
# 3              agree      yes       no       no       no            NaN
# 4  strongly disagree       no       no       no       no            NaN
#
#   synmem               talkedto          tax  teens           teensex  \
# 0    NaN            once a week  about right      0  almst always wrg
# 1    NaN           once a month  about right      1               NaN
# 2    NaN  once in the past year  about right      0               NaN
# 3    NaN                    NaN          NaN      0  not wrong at all
# 4    NaN                    NaN          NaN      0      always wrong
#
#           thnkself ticket              tiredhm1              tiredwk1  \
# 0              NaN    yes  several times a week                 never
# 1    3rd important     no                   NaN                   NaN
# 2  least important    yes                   NaN                   NaN
# 3    3rd important    yes  doesn�t apply/no job  doesn�t apply/no job
# 4   most important     no  doesn�t apply/no job  doesn�t apply/no job
#
#   toldwork            toofast        treatres         trust  \
# 0      NaN                NaN  strongly agree           NaN
# 1      NaN  strongly disagree  strongly agree  cannot trust
# 2      NaN              agree           agree     can trust
# 3      NaN           disagree             NaN     can trust
# 4      NaN              agree             NaN  cannot trust
#
#             trynewjb  tvhours                    twoincs1 unemp  \
# 0  not at all likely        1  neither agree nor disagree   NaN
# 1  not at all likely      NaN                         NaN    no
# 2    somewhat likely      NaN                         NaN   yes
# 3                NaN        4                     disgree    no
# 4                NaN        3                       agree    no
#
#              union  unrelat uscitzn usewww uswar uswary  version vetyears  \
# 0              NaN        0     NaN    NaN   NaN     no        1     none
# 1  neither belongs        0     NaN    NaN   NaN    NaN        3     none
# 2  neither belongs        0     NaN    NaN   NaN    NaN        3     none
# 3  neither belongs        0     NaN    NaN    no    NaN        2     none
# 4  neither belongs      NaN     NaN    NaN   yes    NaN        2     none
#
#   viruses  visart     visitors  vislib  visnhist  vissci  viszoo voedcol  \
# 0     NaN     NaN  no visitors     NaN       NaN     NaN     NaN      no
# 1    True       0  no visitors       0         0       0       0     NaN
# 2   False       0  no visitors       2         1       0       1     NaN
# 3   False       0  no visitors       0         0       0       0      no
# 4    True       0  no visitors      30         1       0       2     yes
#
#   voedncol     voednme1     voednme2 volacty2 volactyr  \
# 0      NaN          NaN          NaN       no       no
# 1       no          NaN          NaN      NaN      NaN
# 2      yes          NaN  high school      NaN      NaN
# 3      NaN          NaN          NaN      NaN      yes
# 4      NaN  jail/prison          NaN      yes       no
#
#                       volchrty volmonth        vote08 webmob  weekswrk  \
# 0  not at all in the past year       no  did not vote    NaN        42
# 1  not at all in the past year       no    ineligible    NaN        30
# 2  not at all in the past year       no         voted    NaN        52
# 3                          NaN      NaN         voted    NaN         0
# 4                          NaN      NaN         voted    NaN         0
#
#    whencol  whenhs where1 where11 where12 where2 where3 where4 where5 where6  \
# 0     2012     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 2      NaN     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    1981    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 4     1964     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
#
#   where7 where8 whoelse1 whoelse2 whoelse3 whoelse4 whoelse5 whoelse6 widowed  \
# 0    NaN    NaN       no       no       no       no       no      yes     NaN
# 1    NaN    NaN       no       no      yes       no       no       no     NaN
# 2    NaN    NaN       no       no      yes       no       no       no      no
# 3    NaN    NaN       no       no       no       no       no      yes      no
# 4    NaN    NaN       no      yes       no       no       no       no      no
#
#   wkageism                  wkbhvrs          wkkidscl          wkkidscs  \
# 0       no  your supervisor or boss               NaN               NaN
# 1       no                      NaN               NaN               NaN
# 2       no  your supervisor or boss               NaN               NaN
# 3      NaN                      NaN  worked full-time  worked full-time
# 4      NaN                      NaN  worked full-time  worked full-time
#
#               wkndact wkracism                      wkrspns     wkstress  \
# 0                 NaN       no  talked to family or friends    sometimes
# 1                 NaN       no                          NaN  hardly ever
# 2                 NaN       no  talked to family or friends        often
# 3  we decide together      NaN                          NaN          NaN
# 4                 NaN      NaN                          NaN          NaN
#
#   wksub wksubs wksup wksups    wkvsfam          wkyngscl          wkyngscs  \
# 0   yes     no    no    NaN  sometimes               NaN               NaN
# 1    no    NaN    no    NaN      never               NaN               NaN
# 2   yes    yes   yes     no      often               NaN               NaN
# 3    no    NaN   yes    yes        NaN  worked full-time  worked full-time
# 4   NaN    NaN   NaN    NaN        NaN  worked full-time  worked full-time
#
#    wlthblks  wlthwhts    worda    wordb      wordc    wordd    worde    wordf  \
# 0         5         4  correct  correct  incorrect  correct  correct  correct
# 1       NaN       NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 2       NaN       NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 3         6         4  correct  correct    correct  correct  correct  correct
# 4         4         4  correct  correct  incorrect  correct  correct  correct
#
#        wordg      wordh    wordi      wordj  wordsum  workblks  \
# 0  incorrect  incorrect  correct    correct        7         4
# 1        NaN        NaN      NaN        NaN      NaN       NaN
# 2        NaN        NaN      NaN        NaN      NaN       NaN
# 3    correct    correct  correct  incorrect        9         4
# 4  incorrect        NaN  correct  incorrect        6         5
#
#          workhard  workwhts         wrkbaby     wrkgovt          wrksch  \
# 0             NaN         4  work part-time     private  work part-time
# 1  most important       NaN             NaN     private             NaN
# 2   2nd important       NaN             NaN     private             NaN
# 3  most important         4             NaN     private             NaN
# 4   2nd important         4       stay home  government  work full-time
#
#          wrkslf           wrkstat        wrkwayup  wwwhr  wwwmin  \
# 0  someone else  working parttime  agree somewhat      5     NaN
# 1  someone else  working parttime             NaN    NaN     NaN
# 2  someone else  working fulltime             NaN    NaN     NaN
# 3  someone else             other  agree strongly     15     NaN
# 4  someone else           retired  agree strongly      4       0
#
#             xmarsex xmovie        xnorcsiz     zodiac
# 0      always wrong    NaN  uninc,med city      libra
# 1      always wrong    yes  uninc,med city      aries
# 2  almst always wrg    yes  uninc,med city      aries
# 3               NaN     no  uninc,med city  capricorn
# 4               NaN     no  city,50-250000     taurus

# %%
data
# Out:
#       Unnamed: 0  year    id      wtss  vpsu  vstrat             res2008  \
# 0              1  2012     1  2.621963     1    3001  living in the u.s.
# 1              2  2012     2  3.495950     1    3001  living in the u.s.
# 2              3  2012     3  1.747975     1    3001  living in the u.s.
# 3              4  2012     4  1.235694     1    3001  living in the u.s.
# 4              5  2012     5  0.873988     1    3001  living in the u.s.
# 5              6  2012     6  0.823796     1    3001  living in the u.s.
# 6              7  2012     7  0.823796     1    3001  living in the u.s.
# 7              8  2012     8  0.411898     1    3001  living in the u.s.
# 8              9  2012     9  0.411898     1    3001  living in the u.s.
# 9             10  2012    10  0.411898     1    3001  living in the u.s.
# 10            11  2012    11  0.823796     2    3001  living in the u.s.
# 11            12  2012    12  0.823796     2    3001  living in the u.s.
# 12            13  2012    13  0.411898     2    3001  living in the u.s.
# 13            14  2012    14  0.411898     2    3001  living in the u.s.
# 14            15  2012    15  1.235694     2    3001  not living in u.s.
# 15            16  2012    16  0.873988     2    3001  living in the u.s.
# 16            17  2012    17  0.823796     2    3001  living in the u.s.
# 17            18  2012    18  1.747975     2    3001  living in the u.s.
# 18            19  2012    19  0.823796     2    3001  living in the u.s.
# 19            20  2012    20  1.647593     2    3001  living in the u.s.
# 20            21  2012    21  3.495950     2    3001  living in the u.s.
# 21            22  2012    22  1.747975     1    3002  living in the u.s.
# 22            23  2012    23  2.621963     1    3002  living in the u.s.
# 23            24  2012    24  1.747975     1    3002  living in the u.s.
# 24            25  2012    25  0.823796     1    3002  living in the u.s.
# 25            26  2012    26  0.823796     1    3002  living in the u.s.
# 26            27  2012    27  4.369938     1    3002  living in the u.s.
# 27            28  2012    28  0.823796     1    3002  living in the u.s.
# 28            29  2012    29  0.411898     1    3002  living in the u.s.
# 29            30  2012    30  0.873988     1    3002  living in the u.s.
# 30            31  2012    31  0.873988     2    3002  living in the u.s.
# 31            32  2012    32  0.411898     2    3002  living in the u.s.
# 32            33  2012    33  1.747975     2    3002  living in the u.s.
# 33            34  2012    34  0.823796     2    3002  living in the u.s.
# 34            35  2012    35  0.873988     2    3002  living in the u.s.
# 35            36  2012    36  0.411898     2    3002  living in the u.s.
# 36            37  2012    37  0.823796     2    3002  living in the u.s.
# 37            38  2012    38  0.823796     2    3002  living in the u.s.
# 38            39  2012    39  0.873988     2    3002  living in the u.s.
# 39            40  2012    40  0.873988     2    3002  living in the u.s.
# 40            41  2012    41  0.823796     2    3002  living in the u.s.
# 41            42  2012    42  1.747975     1    3003  living in the u.s.
# 42            43  2012    43  0.823796     1    3003  living in the u.s.
# 43            44  2012    44  0.411898     1    3003  living in the u.s.
# 44            45  2012    45  1.747975     1    3003  living in the u.s.
# 45            46  2012    46  0.823796     1    3003  living in the u.s.
# 46            47  2012    47  0.823796     1    3003  living in the u.s.
# 47            48  2012    48  0.823796     1    3003  living in the u.s.
# 48            49  2012    49  0.823796     1    3003  living in the u.s.
# 49            50  2012    50  0.411898     1    3003  living in the u.s.
# ...          ...   ...   ...       ...   ...     ...                 ...
# 1924        1925  2012  1925  0.823796     2    3065  living in the u.s.
# 1925        1926  2012  1926  0.411898     2    3065  living in the u.s.
# 1926        1927  2012  1927  0.823796     1    3066  living in the u.s.
# 1927        1928  2012  1928  0.823796     1    3066  living in the u.s.
# 1928        1929  2012  1929  0.411898     1    3066  living in the u.s.
# 1929        1930  2012  1930  0.411898     1    3066  living in the u.s.
# 1930        1931  2012  1931  0.823796     1    3066  living in the u.s.
# 1931        1932  2012  1932  0.411898     1    3066  living in the u.s.
# 1932        1933  2012  1933  0.411898     1    3066  living in the u.s.
# 1933        1934  2012  1934  0.411898     1    3066  living in the u.s.
# 1934        1935  2012  1935  0.823796     1    3066  living in the u.s.
# 1935        1936  2012  1936  0.823796     1    3066  living in the u.s.
# 1936        1937  2012  1937  0.411898     1    3066  living in the u.s.
# 1937        1938  2012  1938  0.823796     1    3066  living in the u.s.
# 1938        1939  2012  1939  0.823796     1    3066  living in the u.s.
# 1939        1940  2012  1940  1.747975     1    3066  living in the u.s.
# 1940        1941  2012  1941  0.411898     1    3066  living in the u.s.
# 1941        1942  2012  1942  0.411898     1    3066  living in the u.s.
# 1942        1943  2012  1943  0.411898     1    3066  living in the u.s.
# 1943        1944  2012  1944  0.873988     1    3066  living in the u.s.
# 1944        1945  2012  1945  0.823796     1    3066  living in the u.s.
# 1945        1946  2012  1946  0.411898     1    3066  living in the u.s.
# 1946        1947  2012  1947  0.411898     1    3066  living in the u.s.
# 1947        1948  2012  1948  1.747975     2    3066  living in the u.s.
# 1948        1949  2012  1949  0.823796     2    3066  living in the u.s.
# 1949        1950  2012  1950  0.823796     2    3066  living in the u.s.
# 1950        1951  2012  1951  0.411898     2    3066  living in the u.s.
# 1951        1952  2012  1952  0.823796     2    3066  living in the u.s.
# 1952        1953  2012  1953  0.411898     2    3066  living in the u.s.
# 1953        1954  2012  1954  1.747975     2    3066  living in the u.s.
# 1954        1955  2012  1955  0.411898     2    3066  living in the u.s.
# 1955        1956  2012  1956  0.823796     2    3066  living in the u.s.
# 1956        1957  2012  1957  0.411898     2    3066  living in the u.s.
# 1957        1958  2012  1958  0.823796     2    3066  living in the u.s.
# 1958        1959  2012  1959  1.235694     2    3066  living in the u.s.
# 1959        1960  2012  1960  0.823796     2    3066  living in the u.s.
# 1960        1961  2012  1961  2.621963     2    3066  living in the u.s.
# 1961        1962  2012  1962  0.823796     2    3066  living in the u.s.
# 1962        1963  2012  1963  0.823796     2    3066  living in the u.s.
# 1963        1964  2012  1964  0.411898     2    3066  living in the u.s.
# 1964        1965  2012  1965  0.823796     2    3066  living in the u.s.
# 1965        1966  2012  1966  0.411898     2    3066  living in the u.s.
# 1966        1967  2012  1967  0.823796     2    3066  living in the u.s.
# 1967        1968  2012  1968  0.411898     2    3066  living in the u.s.
# 1968        1969  2012  1969  1.586220     2    3034  living in the u.s.
# 1969        1970  2012  1970  1.189665     2    3034  living in the u.s.
# 1970        1971  2012  1971  0.396555     2    3034  living in the u.s.
# 1971        1972  2012  1972  1.189665     2    3034  living in the u.s.
# 1972        1973  2012  1973  0.793110     2    3034  living in the u.s.
# 1973        1974  2012  1974  1.586220     2    3034  living in the u.s.
#
#                  res2010  isco88  spisco88    ...             wrksch  \
# 0     living in the u.s.    3429       NaN    ...     work part-time
# 1     living in the u.s.    3132       NaN    ...                NaN
# 2     living in the u.s.    2144      2331    ...                NaN
# 3     living in the u.s.    2411      1233    ...                NaN
# 4     living in the u.s.    5163       NaN    ...     work full-time
# 5     living in the u.s.    2141      8322    ...     work full-time
# 6     living in the u.s.    5220      9312    ...                NaN
# 7     living in the u.s.     NaN       NaN    ...                NaN
# 8     living in the u.s.     NaN       NaN    ...     work part-time
# 9     living in the u.s.    1233       NaN    ...                NaN
# 10    living in the u.s.    1223       NaN    ...                NaN
# 11    living in the u.s.    5131      8322    ...     work full-time
# 12    living in the u.s.     NaN       NaN    ...                NaN
# 13    living in the u.s.    3300       NaN    ...     work full-time
# 14    living in the u.s.    5122       NaN    ...     work part-time
# 15    living in the u.s.    3221       NaN    ...                NaN
# 16    living in the u.s.    9312      8264    ...                NaN
# 17    living in the u.s.    1319       NaN    ...     work full-time
# 18    living in the u.s.    9333       NaN    ...                NaN
# 19    living in the u.s.     NaN       NaN    ...     work full-time
# 20    living in the u.s.    8263       NaN    ...                NaN
# 21    living in the u.s.    9153      3231    ...                NaN
# 22    living in the u.s.    5200      1229    ...     work part-time
# 23    living in the u.s.    3133      2131    ...     work full-time
# 24    living in the u.s.    3112      4121    ...     work part-time
# 25    living in the u.s.    3412      2131    ...                NaN
# 26    living in the u.s.    4115       NaN    ...     work full-time
# 27    living in the u.s.     NaN      3231    ...     work full-time
# 28    living in the u.s.    4115       NaN    ...                NaN
# 29    living in the u.s.    3211       NaN    ...     work part-time
# 30    living in the u.s.    2411       NaN    ...                NaN
# 31    living in the u.s.    4110       NaN    ...     work part-time
# 32    living in the u.s.    2143      2331    ...     work full-time
# 33    not living in u.s.    2131      1231    ...                NaN
# 34    living in the u.s.    5200      8322    ...     work full-time
# 35    living in the u.s.    2446       NaN    ...                NaN
# 36    living in the u.s.    8322      3429    ...                NaN
# 37    living in the u.s.    3231      1319    ...     work full-time
# 38    living in the u.s.    4110       NaN    ...     work full-time
# 39    living in the u.s.    3415       NaN    ...     work full-time
# 40    living in the u.s.    1319      2110    ...                NaN
# 41    living in the u.s.    4215       NaN    ...     work full-time
# 42    living in the u.s.    1319      3152    ...                NaN
# 43    living in the u.s.    1319       NaN    ...                NaN
# 44    living in the u.s.    3411       NaN    ...                NaN
# 45    living in the u.s.    3413      2221    ...                NaN
# 46    living in the u.s.    2331      1210    ...                NaN
# 47    living in the u.s.    2421      2331    ...     work part-time
# 48    living in the u.s.    2452      7510    ...     work part-time
# 49    living in the u.s.     NaN       NaN    ...                NaN
# ...                  ...     ...       ...    ...                ...
# 1924  living in the u.s.    3226      7231    ...     work full-time
# 1925  living in the u.s.    4222       NaN    ...     work full-time
# 1926  living in the u.s.    1235       NaN    ...     work part-time
# 1927  living in the u.s.    3415      4110    ...     work full-time
# 1928  living in the u.s.    9131       NaN    ...     work full-time
# 1929  living in the u.s.    7214       NaN    ...                NaN
# 1930  living in the u.s.    7230      5133    ...     work part-time
# 1931  living in the u.s.     NaN       NaN    ...                NaN
# 1932  living in the u.s.    2331       NaN    ...     work full-time
# 1933  living in the u.s.    5163       NaN    ...     work full-time
# 1934  living in the u.s.    5123       NaN    ...                NaN
# 1935  living in the u.s.    8111      9140    ...          stay home
# 1936  living in the u.s.    2331       NaN    ...                NaN
# 1937  living in the u.s.    5162      3340    ...                NaN
# 1938  living in the u.s.     NaN      9312    ...                NaN
# 1939  living in the u.s.     NaN      3415    ...     work full-time
# 1940  living in the u.s.    3417       NaN    ...                NaN
# 1941  living in the u.s.    9312       NaN    ...     work full-time
# 1942  living in the u.s.    7341       NaN    ...                NaN
# 1943  living in the u.s.    5123       NaN    ...     work full-time
# 1944  living in the u.s.    9132       NaN    ...     work part-time
# 1945  living in the u.s.    7245       NaN    ...                NaN
# 1946  living in the u.s.    3231       NaN    ...     work full-time
# 1947  living in the u.s.    8332       NaN    ...                NaN
# 1948  living in the u.s.    8333      2142    ...                NaN
# 1949  living in the u.s.    1229      6113    ...                NaN
# 1950  living in the u.s.    5220       NaN    ...     work full-time
# 1951  living in the u.s.    4211      2421    ...                NaN
# 1952  living in the u.s.    2230       NaN    ...     work part-time
# 1953  living in the u.s.    9131      5220    ...                NaN
# 1954  living in the u.s.    4114       NaN    ...                NaN
# 1955  living in the u.s.    7231      3152    ...                NaN
# 1956  living in the u.s.    2331       NaN    ...                NaN
# 1957  living in the u.s.    3224      3224    ...                NaN
# 1958  living in the u.s.    2332      8232    ...     work full-time
# 1959  living in the u.s.    1239      4190    ...                NaN
# 1960  living in the u.s.    4222       NaN    ...                NaN
# 1961  living in the u.s.    8322      5141    ...     work part-time
# 1962  living in the u.s.    8141      4211    ...     work part-time
# 1963  living in the u.s.    5131       NaN    ...     work full-time
# 1964  living in the u.s.    2446      1225    ...     work full-time
# 1965  living in the u.s.    8322       NaN    ...                NaN
# 1966  living in the u.s.     NaN      8332    ...          stay home
# 1967  living in the u.s.    9312       NaN    ...                NaN
# 1968  living in the u.s.     NaN       NaN    ...     work part-time
# 1969  living in the u.s.    4222      4213    ...     work part-time
# 1970  living in the u.s.    4115       NaN    ...                NaN
# 1971  living in the u.s.    1239      2446    ...     work full-time
# 1972  living in the u.s.    2332       NaN    ...     work full-time
# 1973  living in the u.s.     NaN       NaN    ...                NaN
#
#              wrkslf           wrkstat                    wrkwayup wwwhr  \
# 0      someone else  working parttime              agree somewhat     5
# 1      someone else  working parttime                         NaN   NaN
# 2      someone else  working fulltime                         NaN   NaN
# 3      someone else             other              agree strongly    15
# 4      someone else           retired              agree strongly     4
# 5      someone else             other              agree somewhat     0
# 6      someone else     keeping house              agree somewhat     2
# 7               NaN     keeping house                         NaN   NaN
# 8               NaN     keeping house              agree strongly   NaN
# 9      someone else  working fulltime                         NaN   NaN
# 10     someone else             other                         NaN    14
# 11              NaN  working parttime              agree somewhat     6
# 12              NaN     keeping house                         NaN   NaN
# 13     someone else             other              agree strongly   NaN
# 14     someone else  working parttime              agree somewhat     1
# 15     someone else  working fulltime                         NaN   NaN
# 16     someone else  working fulltime  neither agree nor disagree     7
# 17     someone else  working fulltime              agree strongly     2
# 18     someone else  working fulltime                         NaN   NaN
# 19              NaN            school              agree somewhat     5
# 20     someone else  unempl, laid off                         NaN   NaN
# 21     someone else  working fulltime                         NaN   NaN
# 22     someone else  working fulltime              agree somewhat     5
# 23     someone else  working fulltime                         NaN   NaN
# 24     someone else           retired              agree strongly     0
# 25     someone else  working fulltime                         NaN   NaN
# 26     someone else  working fulltime              agree somewhat    12
# 27              NaN     keeping house              agree strongly   NaN
# 28     someone else           retired           disagree strongly     1
# 29     someone else  working parttime              agree strongly    20
# 30     someone else           retired                         NaN   NaN
# 31     someone else  working fulltime              agree strongly    10
# 32     someone else           retired           disagree somewhat     4
# 33     someone else  working fulltime                         NaN   NaN
# 34     someone else  working fulltime              agree somewhat     5
# 35     someone else  working fulltime                         NaN   NaN
# 36     someone else  working fulltime              agree somewhat   NaN
# 37     someone else  working fulltime  neither agree nor disagree    40
# 38     someone else  working parttime              agree somewhat    14
# 39     someone else  working fulltime           disagree strongly     7
# 40     someone else  working fulltime                         NaN   NaN
# 41     someone else           retired              agree somewhat     2
# 42     someone else  working fulltime  neither agree nor disagree    10
# 43     someone else  working fulltime                         NaN   NaN
# 44     someone else  working fulltime                         NaN   NaN
# 45     someone else     keeping house              agree strongly     1
# 46     someone else     keeping house                         NaN   NaN
# 47    self-employed  working fulltime              agree strongly     2
# 48    self-employed           retired  neither agree nor disagree    10
# 49     someone else           retired                         NaN   NaN
# ...             ...               ...                         ...   ...
# 1924   someone else  working fulltime  neither agree nor disagree     2
# 1925   someone else     keeping house  neither agree nor disagree     1
# 1926   someone else  working fulltime              agree strongly   NaN
# 1927   someone else  working fulltime              agree strongly     5
# 1928  self-employed  working parttime              agree somewhat    14
# 1929   someone else  unempl, laid off                         NaN   NaN
# 1930   someone else           retired              agree strongly   NaN
# 1931            NaN     keeping house                         NaN   NaN
# 1932   someone else           retired              agree somewhat     4
# 1933   someone else  working fulltime              agree somewhat     1
# 1934   someone else  working parttime                         NaN   NaN
# 1935   someone else  working fulltime  neither agree nor disagree   NaN
# 1936   someone else           retired              agree strongly     4
# 1937   someone else  working fulltime                         NaN   NaN
# 1938            NaN           retired                         NaN   NaN
# 1939   someone else  working fulltime              agree strongly    15
# 1940   someone else  temp not working                         NaN   NaN
# 1941   someone else           retired              agree strongly     3
# 1942   someone else     keeping house                         NaN   NaN
# 1943   someone else  working fulltime              agree strongly    32
# 1944   someone else  unempl, laid off           disagree strongly     3
# 1945   someone else  working fulltime                         NaN   NaN
# 1946   someone else  working fulltime           disagree strongly   NaN
# 1947  self-employed  working fulltime                         NaN   NaN
# 1948  self-employed  unempl, laid off  neither agree nor disagree    10
# 1949   someone else  working fulltime                         NaN   NaN
# 1950   someone else  working parttime              agree somewhat    10
# 1951   someone else  working fulltime  neither agree nor disagree     4
# 1952   someone else  working fulltime           disagree strongly     2
# 1953   someone else  working fulltime                         NaN   NaN
# 1954   someone else           retired  neither agree nor disagree     7
# 1955   someone else  working fulltime                         NaN   NaN
# 1956   someone else  working fulltime  neither agree nor disagree     3
# 1957  self-employed  working fulltime                         NaN   NaN
# 1958   someone else  working fulltime  neither agree nor disagree    14
# 1959   someone else           retired                         NaN   NaN
# 1960   someone else  working parttime                         NaN   NaN
# 1961   someone else           retired              agree strongly   NaN
# 1962   someone else  working parttime              agree somewhat   NaN
# 1963   someone else  working fulltime              agree strongly     2
# 1964   someone else  working fulltime           disagree somewhat     1
# 1965   someone else           retired                         NaN   NaN
# 1966            NaN     keeping house              agree somewhat   NaN
# 1967   someone else           retired                         NaN   NaN
# 1968            NaN     keeping house           disagree somewhat     9
# 1969   someone else  working fulltime              agree strongly     6
# 1970   someone else  unempl, laid off                         NaN   NaN
# 1971   someone else  working fulltime              agree strongly     2
# 1972   someone else  working fulltime              agree strongly   NaN
# 1973            NaN     keeping house                         NaN   NaN
#
#      wwwmin           xmarsex xmovie          xnorcsiz       zodiac
# 0       NaN      always wrong    NaN    uninc,med city        libra
# 1       NaN      always wrong    yes    uninc,med city        aries
# 2       NaN  almst always wrg    yes    uninc,med city        aries
# 3       NaN               NaN     no    uninc,med city    capricorn
# 4         0               NaN     no    city,50-250000       taurus
# 5         0   sometimes wrong    NaN    city,50-250000       taurus
# 6       NaN               NaN     no    city,50-250000      scorpio
# 7       NaN      always wrong     no    city,50-250000      scorpio
# 8       NaN      always wrong    NaN    city,50-250000        libra
# 9       NaN  almst always wrg    yes    city,50-250000       taurus
# 10      NaN   sometimes wrong    NaN  suburb, med city       pisces
# 11      NaN               NaN     no  suburb, med city    capricorn
# 12      NaN      always wrong     no  suburb, med city    capricorn
# 13      NaN      always wrong    NaN  suburb, med city  sagittarius
# 14        0               NaN    yes  suburb, med city  sagittarius
# 15      NaN      always wrong    yes  suburb, med city       pisces
# 16      NaN               NaN     no  suburb, med city       gemini
# 17      NaN               NaN     no  suburb, lrg city       gemini
# 18      NaN      always wrong     no  suburb, lrg city       taurus
# 19      NaN      always wrong    NaN  suburb, lrg city       pisces
# 20      NaN      always wrong     no  suburb, lrg city          leo
# 21      NaN      always wrong    yes  suburb, lrg city       taurus
# 22      NaN               NaN     no  suburb, lrg city       taurus
# 23       10               NaN    yes  suburb, lrg city        libra
# 24        0               NaN     no  suburb, lrg city       pisces
# 25      NaN      always wrong     no  suburb, lrg city      scorpio
# 26      NaN      always wrong    NaN  suburb, lrg city       gemini
# 27      NaN      always wrong    NaN    uninc,med city       pisces
# 28        0               NaN     no    uninc,med city  sagittarius
# 29        0      always wrong    NaN    uninc,med city      scorpio
# 30      NaN      always wrong     no    uninc,med city       cancer
# 31      NaN               NaN     no    uninc,med city        virgo
# 32      NaN               NaN     no    uninc,med city       cancer
# 33      NaN   sometimes wrong    yes    uninc,med city      scorpio
# 34        0               NaN    yes    uninc,med city  sagittarius
# 35      NaN  almst always wrg     no  suburb, lrg city      scorpio
# 36      NaN      always wrong    NaN  suburb, lrg city        aries
# 37        0               NaN     no  suburb, lrg city        virgo
# 38      NaN   sometimes wrong    NaN  suburb, lrg city        libra
# 39        0               NaN    yes  suburb, lrg city       gemini
# 40      NaN  almst always wrg     no  suburb, lrg city        libra
# 41        0               NaN     no  suburb, med city        virgo
# 42        0               NaN     no  suburb, med city    capricorn
# 43      NaN      always wrong     no  suburb, med city        aries
# 44      NaN      always wrong    yes  suburb, med city       cancer
# 45      NaN               NaN     no  suburb, med city    capricorn
# 46      NaN   sometimes wrong     no  suburb, med city       gemini
# 47        0               NaN     no  suburb, med city        virgo
# 48      NaN               NaN     no  suburb, med city          leo
# 49      NaN      always wrong    yes  suburb, med city       pisces
# ...     ...               ...    ...               ...          ...
# 1924    NaN      always wrong    NaN      town gt 2500       cancer
# 1925    NaN               NaN     no      town gt 2500        libra
# 1926    NaN      always wrong    NaN    uninc,med city     aquarius
# 1927    NaN               NaN     no    uninc,med city        aries
# 1928    NaN               NaN     no    uninc,med city  sagittarius
# 1929    NaN   sometimes wrong    yes    uninc,med city        virgo
# 1930    NaN               NaN     no  suburb, med city        libra
# 1931    NaN      always wrong     no    uninc,med city       gemini
# 1932    NaN      always wrong    NaN    uninc,med city    capricorn
# 1933    NaN               NaN     no    uninc,med city    capricorn
# 1934    NaN      always wrong     no    uninc,med city        virgo
# 1935    NaN      always wrong    NaN    uninc,med city        libra
# 1936    NaN               NaN     no    uninc,med city       cancer
# 1937    NaN      always wrong     no    uninc,med city        virgo
# 1938    NaN      always wrong     no    uninc,med city    capricorn
# 1939    NaN               NaN     no    uninc,med city        libra
# 1940    NaN      always wrong     no  suburb, med city       cancer
# 1941    NaN               NaN     no  suburb, med city  sagittarius
# 1942    NaN   sometimes wrong     no  suburb, med city    capricorn
# 1943    NaN      always wrong    NaN  suburb, med city        aries
# 1944      0               NaN    yes  suburb, med city     aquarius
# 1945    NaN      always wrong     no  suburb, med city       gemini
# 1946     30               NaN     no  suburb, med city  sagittarius
# 1947    NaN      always wrong     no      town gt 2500       taurus
# 1948    NaN               NaN     no      town gt 2500        aries
# 1949    NaN      always wrong     no      town gt 2500        aries
# 1950    NaN               NaN     no      town gt 2500       cancer
# 1951    NaN      always wrong    NaN      town gt 2500  sagittarius
# 1952    NaN               NaN     no      town gt 2500        virgo
# 1953    NaN      always wrong     no      town gt 2500        libra
# 1954    NaN               NaN     no      open country        aries
# 1955    NaN      always wrong     no      open country      scorpio
# 1956    NaN               NaN     no      open country     aquarius
# 1957    NaN  almst always wrg     no      open country        libra
# 1958    NaN  almst always wrg    NaN      open country      scorpio
# 1959    NaN  almst always wrg     no      open country  sagittarius
# 1960    NaN      always wrong     no      open country     aquarius
# 1961    NaN               NaN     no      open country          leo
# 1962     30  almst always wrg    NaN      open country       taurus
# 1963      0      always wrong    NaN      open country       gemini
# 1964    NaN               NaN     no      open country      scorpio
# 1965    NaN   sometimes wrong     no      open country       cancer
# 1966    NaN               NaN     no      open country       taurus
# 1967    NaN               NaN     no      open country  sagittarius
# 1968      0      always wrong    NaN  suburb, lrg city       taurus
# 1969      0               NaN     no  suburb, lrg city        aries
# 1970    NaN      always wrong     no  suburb, lrg city       pisces
# 1971      0      always wrong    NaN  suburb, lrg city        virgo
# 1972    NaN               NaN     no  suburb, lrg city        virgo
# 1973    NaN      always wrong     no  suburb, lrg city       pisces
#
# [1974 rows x 819 columns]
